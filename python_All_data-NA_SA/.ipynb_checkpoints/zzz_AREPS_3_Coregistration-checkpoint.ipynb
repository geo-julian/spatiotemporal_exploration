# %%
import Utils

#load the config file
Utils.load_config('config_NA_c1.json')
Utils.print_parameters()

#let's print out some important parameters
#you can change the 'input_file' in config.json to use different mineral deposits. 
#Remember the files we have created in step 2?
print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
#some files should have been created at this point
#let's move to the next cell and check the results
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c1',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'total_sediment_thick',
#                      'seafloor_age',
#                      'conv_rate',
#                      'subducting_abs_rate',
#                      'conv_ortho'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-180, -80, 0, 85],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c1/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c1/deposit_candidates.csv', 'case_AREPS/coreg_input/NA_c1/negative_deposits.csv', 'case_AREPS/coreg_input/NA_c1/positive_deposits.csv']
# processing case_AREPS/coreg_input/NA_c1/deposit_candidates.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 334412
# region of interest: 10
# the length of input data is: 243637
# region of interest: 30
# the length of input data is: 146167
# (334412, 5)
# (334412, 29)
# processing case_AREPS/coreg_input/NA_c1/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 51
# region of interest: 30
# the length of input data is: 10
# (271, 5)
# (271, 29)
# processing case_AREPS/coreg_input/NA_c1/positive_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 26
# region of interest: 30
# the length of input data is: 6
# (271, 5)
# (271, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 304.48248410224915  seconds

# %%
#load the config file
Utils.load_config('config_NA_c2.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c2',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-180, -80, 0, 85],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c2/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c2/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c2/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 58
# region of interest: 30
# the length of input data is: 8
# (271, 5)
# (271, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 26.404563665390015  seconds

# %%
#load the config file
Utils.load_config('config_NA_c3.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c3',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-180, -80, 0, 85],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c3/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c3/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c3/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 52
# region of interest: 30
# the length of input data is: 8
# (271, 5)
# (271, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 33.01864743232727  seconds

# %%
#load the config file
Utils.load_config('config_NA_c4.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c4',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-180, -80, 0, 85],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c4/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c4/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c4/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 53
# region of interest: 30
# the length of input data is: 7
# (271, 5)
# (271, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 25.2898211479187  seconds

# %%
#load the config file
Utils.load_config('config_NA_c5.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c5',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-180, -80, 0, 85],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c5/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c5/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c5/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 271
# region of interest: 10
# the length of input data is: 57
# region of interest: 30
# the length of input data is: 5
# (271, 5)
# (271, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 28.549649477005005  seconds

# %%
#load the config file
Utils.load_config('config_SA_c1.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/SA_c1',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/SA_c1/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/SA_c1/deposit_candidates.csv', 'case_AREPS/coreg_input/SA_c1/negative_deposits.csv', 'case_AREPS/coreg_input/SA_c1/positive_deposits.csv']
# processing case_AREPS/coreg_input/SA_c1/deposit_candidates.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 57114
# region of interest: 10
# the length of input data is: 26904
# region of interest: 30
# the length of input data is: 4258
# (57114, 5)
# (57114, 29)
# processing case_AREPS/coreg_input/SA_c1/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 26
# region of interest: 30
# the length of input data is: 17
# (154, 5)
# (154, 29)
# processing case_AREPS/coreg_input/SA_c1/positive_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 14
# region of interest: 30
# the length of input data is: 9
# (154, 5)
# (154, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 123.9674813747406  seconds

# %%
#load the config file
Utils.load_config('config_SA_c2.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/SA_c2',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/SA_c2/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/SA_c2/negative_deposits.csv']
# processing case_AREPS/coreg_input/SA_c2/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 15
# region of interest: 30
# the length of input data is: 13
# (154, 5)
# (154, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 19.049681663513184  seconds

# %%
#load the config file
Utils.load_config('config_SA_c3.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/SA_c3',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/SA_c3/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/SA_c3/negative_deposits.csv']
# processing case_AREPS/coreg_input/SA_c3/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 16
# region of interest: 30
# the length of input data is: 12
# (154, 5)
# (154, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 20.405250310897827  seconds

# %%
#load the config file
Utils.load_config('config_SA_c4.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/SA_c4',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/SA_c4/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/SA_c4/negative_deposits.csv']
# processing case_AREPS/coreg_input/SA_c4/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 17
# region of interest: 30
# the length of input data is: 10
# (154, 5)
# (154, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 20.968512296676636  seconds

# %%
#load the config file
Utils.load_config('config_SA_c5.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/SA_c5',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'dist_nearest_edge',
#                      'trench_abs_ortho',
#                      'conv_ortho',
#                      'conv_paral'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/SA_c5/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/SA_c5/negative_deposits.csv']
# processing case_AREPS/coreg_input/SA_c5/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 154
# region of interest: 10
# the length of input data is: 17
# region of interest: 30
# the length of input data is: 13
# (154, 5)
# (154, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 19.554245710372925  seconds

# %%
import Utils

#load the config file
Utils.load_config('config_NA_c6.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c6',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'conv_rate',
#                      'conv_angle',
#                      'trench_abs_rate',
#                      'trench_abs_angle',
#                      'arc_len',
#                      'dist_nearest_edge',
#                      'conv_ortho',
#                      'conv_paral',
#                      'trench_abs_ortho',
#                      'trench_abs_paral',
#                      'subducting_abs_rate',
#                      'subducting_abs_angle',
#                      'subducting_abs_ortho',
#                      'subducting_abs_paral',
#                      'seafloor_age',
#                      'carbonate_sediment_thickness',
#                      'total_sediment_thick',
#                      'ocean_crust_carb_percent'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_south_america.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c6/
# The region of interest(in degree):  [5, 10, 30]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c6/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c6/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 187
# region of interest: 10
# the length of input data is: 27
# region of interest: 30
# the length of input data is: 1
# (187, 5)
# (187, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 1.5109636783599854  seconds

# %%
import Utils

#load the config file
Utils.load_config('config_NA_c8.json')
Utils.print_parameters()

print('The file name of the mineral deposits: ', Utils.get_parameter('coreg_input_files'))
print('The output folder: ', Utils.get_coreg_input_dir())
print('The region of interest(in degree): ', Utils.get_parameter('regions'))
print('The subduction convergence kinematics statistics file name template: ', Utils.get_parameter('vector_files'))
print('\n')

import coregistration
coregistration.run() #run the coregistration script
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA_c8',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'conv_rate',
#                      'conv_angle',
#                      'trench_abs_rate',
#                      'trench_abs_angle',
#                      'arc_len',
#                      'dist_nearest_edge',
#                      'conv_ortho',
#                      'conv_paral',
#                      'trench_abs_ortho',
#                      'trench_abs_paral',
#                      'subducting_abs_rate',
#                      'subducting_abs_angle',
#                      'subducting_abs_ortho',
#                      'subducting_abs_paral',
#                      'seafloor_age',
#                      'carbonate_sediment_thickness',
#                      'total_sediment_thick',
#                      'ocean_crust_carb_percent'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}
# The file name of the mineral deposits:  ['deposit_candidates.csv', 'negative_deposits.csv', 'positive_deposits.csv']
# The output folder:  case_AREPS/coreg_input/NA_c8/
# The region of interest(in degree):  [5]
# The subduction convergence kinematics statistics file name template:  ['{conv_dir}subStats_{time:.2f}.csv']
#
#
# running coregistration...
# co-registration input files are:
# ['case_AREPS/coreg_input/NA_c8/negative_deposits.csv']
# processing case_AREPS/coreg_input/NA_c8/negative_deposits.csv ***********************************
# querying {conv_dir}subStats_{time:.2f}.csv
# region of interest: 5
# the length of input data is: 444
# (444, 5)
# (444, 29)
# The coregistration output data have been saved in folder case_AREPS/coreg_output/ successfully!
# Time taken: 5.795706272125244  seconds
