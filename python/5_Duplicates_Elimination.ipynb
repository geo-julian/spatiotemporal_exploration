# %%
import pandas as pd


NA_candidates = pd.read_csv('case_AREPS/coreg_output/NA/deposit_candidates.csv', sep=",")
NA_positives = pd.read_csv('case_AREPS/coreg_output/NA/positive_deposits.csv', sep=",")
NA_negatives = pd.read_csv('case_AREPS/coreg_output/NA/negative_deposits.csv', sep=",")

SA_candidates = pd.read_csv('case_AREPS/coreg_output/SA/deposit_candidates.csv', sep=",")
SA_positives = pd.read_csv('case_AREPS/coreg_output/SA/positive_deposits.csv', sep=",")
SA_negatives = pd.read_csv('case_AREPS/coreg_output/SA/negative_deposits.csv', sep=",")

#NA_candidates = NA_candidates['conv_rate'].dropna()
print('NA_candidates')
print(NA_candidates.shape)
NA_candidates = NA_candidates.dropna(subset=['conv_rate'])
print(NA_candidates.shape)
NA_candidates = NA_candidates.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(NA_candidates.shape)
print('')

print('NA_positives')
print(NA_positives.shape)
NA_positives = NA_positives.dropna(subset=['conv_rate'])
print(NA_positives.shape)
NA_positives = NA_positives.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(NA_positives.shape)
print('')

print('NA_negatives')
print(NA_negatives.shape)
NA_negatives = NA_negatives.dropna(subset=['conv_rate'])
print(NA_negatives.shape)
NA_negatives = NA_negatives.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(NA_negatives.shape)
print('')

print('SA_candidates')
print(SA_candidates.shape)
SA_candidates = SA_candidates.dropna(subset=['conv_rate'])
print(SA_candidates.shape)
SA_candidates = SA_candidates.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(SA_candidates.shape)
print('')

print('SA_positives')
print(SA_positives.shape)
SA_positives = SA_positives.dropna(subset=['conv_rate'])
print(SA_positives.shape)
SA_positives = SA_positives.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(SA_positives.shape)
print('')

print('SA_negatives')
print(SA_negatives.shape)
SA_negatives = SA_negatives.dropna(subset=['conv_rate'])
print(SA_negatives.shape)
SA_negatives = SA_negatives.drop_duplicates(subset=['recon_lon', 'recon_lat'],keep='first')
print(SA_negatives.shape)
print('')

NA_candidates.to_csv('case_AREPS/coreg_output_clean/NA/deposit_candidates.csv', index=False)
NA_positives.to_csv('case_AREPS/coreg_output_clean/NA/positive_deposits.csv', index=False)
NA_negatives.to_csv('case_AREPS/coreg_output_clean/NA/negative_deposits.csv', index=False)

SA_candidates.to_csv('case_AREPS/coreg_output_clean/SA/deposit_candidates.csv', index=False)
SA_positives.to_csv('case_AREPS/coreg_output_clean/SA/positive_deposits.csv', index=False)
SA_negatives.to_csv('case_AREPS/coreg_output_clean/SA/negative_deposits.csv', index=False)
# Out:
# NA_candidates
# (219244, 33)
# (60324, 33)
# (60295, 33)
#
# NA_positives
# (272, 33)
# (246, 33)
# (239, 33)
#
# NA_negatives
# (58, 33)
# (57, 33)
# (57, 33)
#
# SA_candidates
# (132396, 33)
# (61065, 33)
# (61064, 33)
#
# SA_positives
# (155, 33)
# (150, 33)
# (150, 33)
#
# SA_negatives
# (634, 33)
# (628, 33)
# (606, 33)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import pandas as pd
import Utils

deposits_file_name = 'case_AREPS/coreg_output_clean/NA/deposit_candidates.csv'
map_extent = [-180, -80, 0, 85], #North America
#map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-180, -80, 0, 85])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Candidate Deposits North America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the candidate deposits from North America...")
display(data)
# Out:
# Here are the candidate deposits from North America...
#           lon    lat    age  plate_id  recon_lon  recon_lat  distance  \
# 0     -148.28  63.00    0.0   16110.0   -148.280     63.000     0.054
# 1     -105.00  22.72    0.0     104.0   -105.000     22.720     0.027
# 2     -123.85  51.58    0.0   16101.0   -123.850     51.580     0.061
# 3     -141.44  60.43    0.0   16121.0   -141.440     60.430     0.026
# 4     -140.30  64.94    0.0     154.0   -140.300     64.940     0.085
# ...       ...    ...    ...       ...        ...        ...       ...
# 60290 -122.02  39.18  230.0     176.0    -59.427     11.343     0.034
# 60291 -121.03  38.36  230.0     176.0    -59.183     10.242     0.035
# 60292 -121.44  37.23  230.0     176.0    -60.051      9.436     0.019
# 60293 -123.04  39.99  230.0     176.0    -59.679     12.444     0.031
# 60294 -119.52  35.57  230.0     176.0    -59.546      7.224     0.019
#
#        sub_idx  trench_lon  trench_lat  ...  trench_abs_paral  \
# 0        294.0     -144.44       60.46  ...             -1.35
# 1        368.0     -105.80       21.39  ...              1.95
# 2        303.0     -128.50       49.71  ...              1.02
# 3        294.0     -144.44       60.46  ...             -1.35
# 4        294.0     -144.44       60.46  ...             -1.35
# ...        ...         ...         ...  ...               ...
# 60290   1023.0      -61.38       11.01  ...             -2.41
# 60291   1036.0      -61.24       10.06  ...             -2.41
# 60292   1050.0      -61.08        9.10  ...             -2.40
# 60293   1027.0      -61.35       13.09  ...             -2.16
# 60294   1092.0      -60.61        6.99  ...             -2.40
#
#        subducting_abs_rate  subducting_abs_angle  subducting_abs_ortho  \
# 0                    -3.29                 -3.97                  3.28
# 1                     1.35                152.96                 -1.20
# 2                    -2.71                 27.81                  2.40
# 3                    -3.29                 -3.97                  3.28
# 4                    -3.29                 -3.97                  3.28
# ...                    ...                   ...                   ...
# 60290                -3.83                 -4.44                  3.82
# 60291                -3.72                 -4.57                  3.71
# 60292                -3.61                 -0.20                  3.61
# 60293                -4.05                -32.01                  3.44
# 60294                -3.36                 -0.21                  3.36
#
#        subducting_abs_paral  seafloor_age  subduction_volume_km3y  \
# 0                     -0.23         34.77                    0.06
# 1                      0.61          9.76                    0.00
# 2                      1.27          3.05                    0.01
# 3                     -0.23         34.77                    0.06
# 4                     -0.23         34.77                    0.06
# ...                     ...           ...                     ...
# 60290                 -0.30         28.78                    0.04
# 60291                 -0.30         33.06                    0.05
# 60292                 -0.01         37.12                    0.05
# 60293                 -2.15         23.06                    0.05
# 60294                 -0.01         44.14                    0.05
#
#        carbonate_sediment_thickness  total_sediment_thick  \
# 0                             88.12                 98.17
# 1                             63.23                248.67
# 2                             10.07                 46.90
# 3                             88.12                 98.17
# 4                             88.12                 98.17
# ...                             ...                   ...
# 60290                          0.00                138.89
# 60291                          0.00                151.11
# 60292                          0.00                155.45
# 60293                          0.00                122.98
# 60294                          0.00                155.70
#
#        ocean_crust_carb_percent
# 0                          1.87
# 1                          1.23
# 2                          0.73
# 3                          1.87
# 4                          1.87
# ...                         ...
# 60290                      2.42
# 60291                      2.29
# 60292                      2.05
# 60293                      2.41
# 60294                      1.83
#
# [60295 rows x 33 columns]

# %%
deposits_file_name = 'case_AREPS/coreg_output_clean/NA/positive_deposits.csv'
map_extent = [-180, -80, 0, 85], #North America
#map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-180, -80, 0, 85])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Mineral Deposits North America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the mineral deposits from North America...")
display(data)
# Out:
# Here are the mineral deposits from North America...
#         lon    lat    age  plate_id  recon_lon  recon_lat  distance  sub_idx  \
# 0   -157.24  57.05    1.0   16112.0   -157.230     57.204     0.034    256.0
# 1   -158.40  56.52    4.0   16112.0   -158.368     57.134     0.033    239.0
# 2   -127.85  50.68    5.0   16110.0   -127.112     51.567     0.017    295.0
# 3   -157.24  57.05    6.0   16112.0   -157.178     57.984     0.034    252.0
# 4   -127.58  50.33    6.0   16110.0   -126.684     51.395     0.015    298.0
# ..      ...    ...    ...       ...        ...        ...       ...      ...
# 234 -121.05  50.49  210.0   16102.0    -53.566     26.277     0.066   1226.0
# 235 -121.00  50.43  210.0   16102.0    -53.569     26.209     0.066   1226.0
# 236 -131.88  58.24  218.0   16101.0    -53.121     33.298     0.036   1446.0
# 237 -126.68  57.22  221.0   16102.0    -51.141     29.781     0.064   1459.0
# 238 -130.99  57.36  222.0   16101.0    -53.135     31.187     0.033   1472.0
#
#      trench_lon  trench_lat  ...  trench_abs_paral  subducting_abs_rate  \
# 0       -154.65       55.91  ...             -1.35                -4.24
# 1       -156.47       55.59  ...             -1.15                -4.34
# 2       -128.33       50.98  ...              0.68                -2.71
# 3       -154.51       56.71  ...             -1.39                -4.11
# 4       -127.81       50.91  ...              0.68                -2.70
# ..          ...         ...  ...               ...                  ...
# 234      -57.72       27.03  ...             -3.39                -3.95
# 235      -57.72       27.03  ...             -3.39                -3.95
# 236      -55.56       33.40  ...             -3.92                -4.49
# 237      -55.39       30.09  ...             -2.29                -5.50
# 238      -55.32       31.28  ...             -2.29                -5.63
#
#      subducting_abs_angle  subducting_abs_ortho  subducting_abs_paral  \
# 0                   -3.32                  4.24                 -0.25
# 1                  -12.85                  4.23                 -0.97
# 2                   34.67                  2.23                  1.54
# 3                   -2.41                  4.11                 -0.17
# 4                   34.36                  2.23                  1.52
# ..                    ...                   ...                   ...
# 234                -32.79                  3.32                 -2.14
# 235                -32.79                  3.32                 -2.14
# 236                -13.77                  4.36                 -1.07
# 237                 -3.51                  5.49                 -0.34
# 238                 -3.44                  5.62                 -0.34
#
#      seafloor_age  subduction_volume_km3y  carbonate_sediment_thickness  \
# 0           47.06                    0.07                         62.19
# 1           43.90                    0.06                         49.88
# 2            2.05                    0.01                          5.43
# 3           35.51                    0.06                         64.67
# 4            3.36                    0.02                         11.89
# ..            ...                     ...                           ...
# 234         32.98                    0.07                          0.00
# 235         32.98                    0.07                          0.00
# 236         33.91                    0.08                          0.00
# 237         38.80                    0.08                          0.00
# 238         37.33                    0.08                          0.00
#
#      total_sediment_thick  ocean_crust_carb_percent
# 0                  112.85                      2.21
# 1                  111.62                      2.19
# 2                   45.41                      1.12
# 3                   99.47                      2.08
# 4                   47.51                      1.13
# ..                    ...                       ...
# 234                 95.38                      2.38
# 235                 95.38                      2.38
# 236                 96.80                      2.48
# 237                108.76                      2.54
# 238                166.64                      2.53
#
# [239 rows x 33 columns]

# %%
deposits_file_name = 'case_AREPS/coreg_output_clean/NA/negative_deposits.csv'
map_extent = [-180, -80, 0, 85], #North America
#map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-180, -80, 0, 85])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Volcanic Rocks North America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the negative deposits from North America...")
display(data)
# Out:
# Here are the negative deposits from North America...
#         lon     lat  age  plate_id  recon_lon  recon_lat  distance  sub_idx  \
# 0  -153.092  60.032  0.0   16112.0   -153.092     60.032     0.042    275.0
# 1  -153.435  59.363  0.0   16112.0   -153.435     59.363     0.036    273.0
# 2  -153.535  58.860  0.0   16112.0   -153.535     58.860     0.030    270.0
# 3  -153.674  58.770  0.0   16112.0   -153.674     58.770     0.030    270.0
# 4  -154.357  58.453  0.0   16112.0   -154.357     58.453     0.031    267.0
# 5  -154.686  58.334  0.0   16112.0   -154.686     58.334     0.032    267.0
# 6  -154.953  58.279  0.0   16112.0   -154.953     58.279     0.033    265.0
# 7  -155.103  58.234  0.0   16112.0   -155.103     58.234     0.033    265.0
# 8  -155.104  58.357  0.0   16112.0   -155.104     58.357     0.035    265.0
# 9  -155.159  58.265  0.0   16112.0   -155.159     58.265     0.034    265.0
# 10 -155.254  58.195  0.0   16112.0   -155.254     58.195     0.034    265.0
# 11 -155.357  58.169  0.0   16112.0   -155.357     58.169     0.034    265.0
# 12 -156.370  57.750  0.0   16112.0   -156.370     57.750     0.036    261.0
# 13 -156.514  57.834  0.0   16112.0   -156.514     57.834     0.038    261.0
# 14 -156.991  57.133  0.0   16112.0   -156.991     57.133     0.033    257.0
# 15 -158.209  56.906  0.0   16112.0   -158.209     56.906     0.037    249.0
# 16 -159.393  56.198  0.0   16112.0   -159.393     56.198     0.034    244.0
# 17 -159.791  56.013  0.0   16112.0   -159.791     56.013     0.034    243.0
# 18 -161.894  55.417  0.0   16112.0   -161.894     55.417     0.035    232.0
# 19 -162.073  55.341  0.0   16112.0   -162.073     55.341     0.034    232.0
# 20 -162.274  55.187  0.0   16112.0   -162.274     55.187     0.032    231.0
# 21 -163.147  55.417  0.0   16112.0   -163.147     55.417     0.040    229.0
# 22 -163.971  54.755  0.0   16112.0   -163.971     54.755     0.033    225.0
# 23 -164.352  54.669  0.0   16112.0   -164.352     54.669     0.033    224.0
# 24 -164.648  54.517  0.0   16112.0   -164.648     54.517     0.032    222.0
# 25 -165.661  54.252  0.0   16112.0   -165.661     54.252     0.031    218.0
# 26 -165.986  54.133  0.0   16112.0   -165.986     54.133     0.030    217.0
# 27 -166.932  53.887  0.0   16112.0   -166.932     53.887     0.029    214.0
# 28 -168.034  53.927  0.0   16112.0   -168.034     53.927     0.034    211.0
# 29 -168.132  53.419  0.0   16112.0   -168.132     53.419     0.026    210.0
# 30 -168.538  53.154  0.0   16112.0   -168.538     53.154     0.023    208.0
# 31 -168.694  53.126  0.0   16112.0   -168.694     53.126     0.023    208.0
# 32 -169.717  52.973  0.0   16130.0   -169.717     52.973     0.025    204.0
# 33 -169.758  52.839  0.0   16130.0   -169.758     52.839     0.022    203.0
# 34 -169.945  52.822  0.0   16130.0   -169.945     52.822     0.023    203.0
# 35 -170.058  52.891  0.0   16130.0   -170.058     52.891     0.024    203.0
# 36 -170.113  52.741  0.0   16130.0   -170.113     52.741     0.022    203.0
# 37 -170.652  52.644  0.0   16130.0   -170.652     52.644     0.022    201.0
# 38 -171.255  52.494  0.0   16130.0   -171.255     52.494     0.021    199.0
# 39 -172.510  52.316  0.0   16130.0   -172.510     52.316     0.023    195.0
# 40 -174.139  52.331  0.0   16130.0   -174.139     52.331     0.027    158.0
# 41 -174.155  52.379  0.0   16130.0   -174.155     52.379     0.028    158.0
# 42  -99.663  19.185  0.0     215.0    -99.663     19.185     0.048    406.0
# 43  -99.756  19.119  0.0     215.0    -99.756     19.119     0.047    406.0
# 44  -99.756  19.106  0.0     215.0    -99.756     19.106     0.046    406.0
# 45  -99.765  19.116  0.0     215.0    -99.765     19.116     0.046    405.0
# 46  -99.775  18.855  0.0     215.0    -99.775     18.855     0.042    406.0
# 47  -99.790  19.223  0.0     215.0    -99.790     19.223     0.048    405.0
# 48  -99.800  19.138  0.0     215.0    -99.800     19.138     0.047    405.0
# 49  -99.802  19.143  0.0     215.0    -99.802     19.143     0.047    405.0
# 50 -103.855  20.853  0.0     104.0   -103.855     20.853     0.032    364.0
# 51 -103.855  20.853  3.0     104.0   -103.337     21.337     0.032    367.0
# 52 -103.855  20.853  5.0     104.0   -102.989     21.657     0.032    376.0
# 53 -120.549  50.770  0.0   16102.0   -120.549     50.770     0.085    315.0
# 54 -120.640  49.562  0.0   16102.0   -120.640     49.562     0.074    316.0
# 55 -128.374  52.264  3.0   16110.0   -127.942     52.796     0.032    286.0
# 56 -128.437  52.296  3.0   16110.0   -128.005     52.828     0.032    286.0
#
#     trench_lon  trench_lat  ...  trench_abs_paral  subducting_abs_rate  \
# 0      -150.04       58.21  ...             -1.39                -3.79
# 1      -150.57       57.95  ...             -1.39                -3.85
# 2      -151.35       57.56  ...             -1.39                -3.92
# 3      -151.35       57.56  ...             -1.39                -3.92
# 4      -152.11       57.16  ...             -1.39                -4.00
# 5      -152.11       57.16  ...             -1.39                -4.00
# 6      -152.61       56.89  ...             -1.39                -4.05
# 7      -152.61       56.89  ...             -1.39                -4.05
# 8      -152.61       56.89  ...             -1.39                -4.05
# 9      -152.61       56.89  ...             -1.39                -4.05
# 10     -152.61       56.89  ...             -1.39                -4.05
# 11     -152.61       56.89  ...             -1.39                -4.05
# 12     -153.59       56.35  ...             -1.39                -4.16
# 13     -153.59       56.35  ...             -1.39                -4.16
# 14     -154.47       55.86  ...             -1.35                -4.25
# 15     -156.33       55.04  ...             -0.96                -4.42
# 16     -157.46       54.59  ...             -1.14                -4.52
# 17     -157.70       54.48  ...             -1.14                -4.55
# 18     -160.68       53.56  ...             -0.71                -4.78
# 19     -160.68       53.56  ...             -0.71                -4.78
# 20     -160.97       53.49  ...             -0.71                -4.80
# 21     -161.56       53.34  ...             -0.71                -4.85
# 22     -162.73       53.04  ...             -0.71                -4.93
# 23     -163.02       52.97  ...             -0.71                -4.95
# 24     -163.61       52.82  ...             -0.54                -4.99
# 25     -164.84       52.57  ...             -0.54                -5.08
# 26     -165.14       52.51  ...             -0.54                -5.10
# 27     -166.05       52.31  ...             -0.54                -5.16
# 28     -166.96       52.10  ...             -0.54                -5.22
# 29     -167.25       52.04  ...             -0.54                -5.24
# 30     -167.85       51.89  ...             -0.54                -5.28
# 31     -167.85       51.89  ...             -0.54                -5.28
# 32     -169.04       51.63  ...             -0.40                -5.36
# 33     -169.33       51.58  ...             -0.40                -5.38
# 34     -169.33       51.58  ...             -0.40                -5.38
# 35     -169.33       51.58  ...             -0.40                -5.38
# 36     -169.33       51.58  ...             -0.40                -5.38
# 37     -169.93       51.46  ...             -0.40                -5.41
# 38     -170.52       51.35  ...             -0.40                -5.45
# 39     -171.70       51.10  ...             -0.40                -5.53
# 40     -173.76       50.78  ...             -0.04                -5.65
# 41     -173.76       50.78  ...             -0.04                -5.65
# 42     -100.79       16.64  ...             -0.92                -3.31
# 43     -100.79       16.64  ...             -0.92                -3.31
# 44     -100.79       16.64  ...             -0.92                -3.31
# 45     -100.96       16.71  ...             -0.92                -3.26
# 46     -100.79       16.64  ...             -0.92                -3.31
# 47     -100.96       16.71  ...             -0.92                -3.26
# 48     -100.96       16.71  ...             -0.92                -3.26
# 49     -100.96       16.71  ...             -0.92                -3.26
# 50     -105.83       21.01  ...              1.95                 1.13
# 51     -105.32       21.50  ...              1.94                 1.74
# 52     -104.97       21.83  ...              1.94                 1.70
# 53     -126.61       47.93  ...              0.91                -2.67
# 54     -126.45       47.79  ...              0.91                -2.67
# 55     -129.60       51.25  ...              0.77                -2.73
# 56     -129.60       51.25  ...              0.77                -2.73
#
#     subducting_abs_angle  subducting_abs_ortho  subducting_abs_paral  \
# 0                  -1.36                  3.79                 -0.09
# 1                  -1.34                  3.84                 -0.09
# 2                  -1.32                  3.92                 -0.09
# 3                  -1.32                  3.92                 -0.09
# 4                  -1.29                  4.00                 -0.09
# 5                  -1.29                  4.00                 -0.09
# 6                  -1.28                  4.05                 -0.09
# 7                  -1.28                  4.05                 -0.09
# 8                  -1.28                  4.05                 -0.09
# 9                  -1.28                  4.05                 -0.09
# 10                 -1.28                  4.05                 -0.09
# 11                 -1.28                  4.05                 -0.09
# 12                 -1.24                  4.16                 -0.09
# 13                 -1.24                  4.16                 -0.09
# 14                 -3.52                  4.24                 -0.26
# 15                -20.28                  4.15                 -1.53
# 16                -12.19                  4.42                 -0.95
# 17                -12.12                  4.45                 -0.95
# 18                -28.67                  4.20                 -2.29
# 19                -28.67                  4.20                 -2.29
# 20                -28.53                  4.22                 -2.29
# 21                -28.26                  4.27                 -2.29
# 22                -27.73                  4.36                 -2.29
# 23                -27.60                  4.39                 -2.29
# 24                -33.66                  4.16                 -2.77
# 25                -33.05                  4.25                 -2.77
# 26                -32.90                  4.28                 -2.77
# 27                -32.46                  4.35                 -2.77
# 28                -32.03                  4.42                 -2.77
# 29                -31.89                  4.45                 -2.77
# 30                -31.62                  4.50                 -2.77
# 31                -31.62                  4.50                 -2.77
# 32                -36.78                  4.29                 -3.21
# 33                -36.63                  4.31                 -3.21
# 34                -36.63                  4.31                 -3.21
# 35                -36.63                  4.31                 -3.21
# 36                -36.63                  4.31                 -3.21
# 37                -36.34                  4.36                 -3.21
# 38                -36.05                  4.41                 -3.21
# 39                -35.49                  4.50                 -3.21
# 40                -49.61                  3.66                 -4.30
# 41                -49.61                  3.66                 -4.30
# 42                 12.13                  3.23                  0.70
# 43                 12.13                  3.23                  0.70
# 44                 12.13                  3.23                  0.70
# 45                 12.31                  3.19                  0.70
# 46                 12.13                  3.23                  0.70
# 47                 12.31                  3.19                  0.70
# 48                 12.31                  3.19                  0.70
# 49                 12.31                  3.19                  0.70
# 50                147.25                 -0.95                  0.61
# 51               -142.05                 -1.37                 -1.07
# 52                 98.92                 -0.26                  1.68
# 53                 31.33                  2.28                  1.39
# 54                 31.38                  2.28                  1.39
# 55                 32.99                  2.29                  1.48
# 56                 32.99                  2.29                  1.48
#
#     seafloor_age  subduction_volume_km3y  carbonate_sediment_thickness  \
# 0          39.36                    0.07                         75.80
# 1          39.36                    0.07                         68.81
# 2          42.02                    0.07                         68.81
# 3          42.02                    0.07                         68.81
# 4          42.02                    0.07                         68.81
# 5          42.02                    0.07                         68.81
# 6          42.02                    0.07                         68.81
# 7          42.02                    0.07                         68.81
# 8          42.02                    0.07                         68.81
# 9          42.02                    0.07                         68.81
# 10         42.02                    0.07                         68.81
# 11         42.02                    0.07                         68.81
# 12         44.17                    0.08                         66.30
# 13         44.17                    0.08                         66.30
# 14         44.17                    0.07                         66.30
# 15         51.20                    0.07                         42.53
# 16         52.25                    0.09                         41.87
# 17         52.03                    0.09                         41.87
# 18         51.34                    0.09                         37.06
# 19         51.34                    0.09                         37.06
# 20         53.51                    0.09                         37.06
# 21         53.48                    0.09                         37.46
# 22         53.42                    0.09                         37.46
# 23         53.42                    0.09                         37.46
# 24         54.13                    0.09                         33.68
# 25         54.21                    0.09                         33.91
# 26         54.21                    0.09                         33.91
# 27         57.04                    0.10                         34.17
# 28         57.23                    0.10                         34.30
# 29         57.23                    0.10                         34.30
# 30         57.40                    0.10                         34.30
# 31         57.40                    0.10                         34.30
# 32         57.55                    0.10                         34.67
# 33         57.55                    0.10                         34.67
# 34         57.55                    0.10                         34.67
# 35         57.55                    0.10                         34.67
# 36         57.55                    0.10                         34.67
# 37         62.20                    0.10                         34.94
# 38         62.26                    0.10                         34.94
# 39         62.29                    0.10                         34.94
# 40         57.40                    0.08                         35.30
# 41         57.40                    0.08                         35.30
# 42         11.54                    0.04                         77.00
# 43         11.54                    0.04                         77.00
# 44         11.54                    0.04                         77.00
# 45         11.54                    0.04                         77.00
# 46         11.54                    0.04                         77.00
# 47         11.54                    0.04                         77.00
# 48         11.54                    0.04                         77.00
# 49         11.54                    0.04                         77.00
# 50          9.76                    0.00                         63.23
# 51          6.92                    0.00                         31.88
# 52          5.48                    0.01                         12.75
# 53          5.58                    0.02                         23.94
# 54          5.58                    0.02                         43.73
# 55          1.26                    0.01                         22.27
# 56          1.26                    0.01                         22.27
#
#     total_sediment_thick  ocean_crust_carb_percent
# 0                 105.85                      2.04
# 1                 105.85                      2.04
# 2                 108.47                      2.06
# 3                 108.47                      2.06
# 4                 108.47                      2.06
# 5                 108.47                      2.06
# 6                 108.47                      2.06
# 7                 108.47                      2.06
# 8                 108.47                      2.06
# 9                 108.47                      2.06
# 10                108.47                      2.06
# 11                108.47                      2.06
# 12                112.26                      2.14
# 13                112.26                      2.14
# 14                112.26                      2.14
# 15                121.58                      2.22
# 16                122.87                      2.22
# 17                122.54                      2.21
# 18                121.63                      2.21
# 19                121.63                      2.21
# 20                124.31                      2.20
# 21                124.21                      2.19
# 22                124.16                      2.19
# 23                124.16                      2.19
# 24                125.03                      2.19
# 25                125.13                      2.19
# 26                125.13                      2.19
# 27                128.33                      2.18
# 28                128.54                      2.18
# 29                128.54                      2.18
# 30                128.73                      2.18
# 31                128.73                      2.18
# 32                128.88                      2.18
# 33                128.88                      2.18
# 34                128.88                      2.18
# 35                128.88                      2.18
# 36                128.88                      2.18
# 37                133.69                      2.16
# 38                133.73                      2.16
# 39                133.73                      2.16
# 40                128.70                      2.18
# 41                128.70                      2.18
# 42                 60.14                      1.38
# 43                 60.14                      1.38
# 44                 60.14                      1.38
# 45                 60.14                      1.38
# 46                 60.14                      1.38
# 47                 60.14                      1.38
# 48                 60.14                      1.38
# 49                 60.14                      1.38
# 50                248.67                      1.23
# 51                266.39                      1.21
# 52                244.68                      1.21
# 53                 50.87                      1.11
# 54                 50.87                      1.11
# 55                 44.20                      0.73
# 56                 44.20                      0.73
#
# [57 rows x 33 columns]

# %%
deposits_file_name = 'case_AREPS/coreg_output_clean/SA/deposit_candidates.csv'
#map_extent = [-180, -80, 0, 85], #North America
map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-85, -29, -55, 15])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Candidate Deposits South America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the candidate deposits from South America...")
display(data)
# Out:
# Here are the candidate deposits from South America...
#          lon    lat    age  plate_id  recon_lon  recon_lat  distance  sub_idx  \
# 0     -69.09 -30.00    0.0     202.0    -69.090    -30.000     0.049    858.0
# 1     -77.17   7.63    0.0     201.0    -77.170      7.630     0.021    648.0
# 2     -77.17  -7.63    0.0     201.0    -77.170     -7.630     0.065    566.0
# 3     -66.04 -22.56    0.0     201.0    -66.040    -22.560     0.082    916.0
# 4     -71.80 -15.31    0.0     201.0    -71.800    -15.310     0.046    817.0
# ...      ...    ...    ...       ...        ...        ...       ...      ...
# 61059 -70.28 -45.71  230.0     283.0    -55.849    -66.340     0.071    860.0
# 61060 -71.40 -47.64  230.0   28800.0    -57.124    -68.199     0.063    848.0
# 61061 -69.87 -47.63  230.0   28800.0    -54.358    -68.129     0.081    850.0
# 61062 -70.83 -46.67  230.0   28800.0    -56.230    -67.211     0.067    853.0
# 61063 -67.02 -30.67  230.0     202.0    -50.669    -49.939     0.081   1373.0
#
#        trench_lon  trench_lat  ...  trench_abs_paral  subducting_abs_rate  \
# 0          -72.30      -29.74  ...              0.77                -7.22
# 1          -78.15        8.31  ...              1.68                -0.78
# 2          -80.66       -9.05  ...             -0.17                -6.34
# 3          -71.10      -22.37  ...              0.74                -7.04
# 4          -73.79      -17.13  ...             -0.91                -6.82
# ...           ...         ...  ...               ...                  ...
# 61059      -66.00      -66.73  ...             -2.23                -5.11
# 61060      -66.35      -67.22  ...             -1.75                -5.19
# 61061      -66.19      -67.05  ...             -1.89                -5.16
# 61062      -66.06      -66.89  ...             -1.89                -5.14
# 61063      -57.49      -48.69  ...             -1.67                -2.73
#
#        subducting_abs_angle  subducting_abs_ortho  subducting_abs_paral  \
# 0                    -15.93                  6.94                 -1.98
# 1                      6.94                  0.78                  0.09
# 2                     15.70                  6.10                  1.72
# 3                    -15.94                  6.77                 -1.93
# 4                     34.19                  5.64                  3.83
# ...                     ...                   ...                   ...
# 61059                 -9.62                  5.04                 -0.85
# 61060                -33.25                  4.34                 -2.85
# 61061                -28.24                  4.55                 -2.44
# 61062                -28.40                  4.52                 -2.44
# 61063                -73.28                  0.79                 -2.62
#
#        seafloor_age  subduction_volume_km3y  carbonate_sediment_thickness  \
# 0             40.40                    0.12                         56.27
# 1            189.04                    0.04                         74.17
# 2             30.99                    0.10                        103.54
# 3             53.13                    0.13                         37.23
# 4             52.50                    0.12                         42.30
# ...             ...                     ...                           ...
# 61059         85.19                    0.09                          0.18
# 61060         85.19                    0.11                          0.06
# 61061         85.19                    0.10                          0.06
# 61062         85.19                    0.10                          0.18
# 61063         66.57                    0.04                          0.86
#
#        total_sediment_thick  ocean_crust_carb_percent
# 0                    106.76                      2.02
# 1                    370.05                      2.23
# 2                     93.79                      2.02
# 3                    123.90                      2.22
# 4                    123.18                      2.22
# ...                     ...                       ...
# 61059                148.77                      0.76
# 61060                148.77                      0.76
# 61061                148.77                      0.76
# 61062                148.77                      0.76
# 61063                136.39                      0.73
#
# [61064 rows x 33 columns]

# %%
deposits_file_name = 'case_AREPS/coreg_output_clean/SA/positive_deposits.csv'
#map_extent = [-180, -80, 0, 85], #North America
map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-85, -29, -55, 15])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Mineral Deposits South America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the mineral deposits from South America...")
display(data)
# Out:
# Here are the mineral deposits from South America...
#        lon    lat    age  plate_id  recon_lon  recon_lat  distance  sub_idx  \
# 0   -66.28 -27.37    6.0     202.0    -65.220    -27.064     0.083    899.0
# 1   -69.37 -31.30  170.0     202.0    -45.406    -32.470     0.046    980.0
# 2   -69.75 -30.50   12.0     202.0    -67.521    -29.967     0.039    921.0
# 3   -66.65 -27.27    9.0     202.0    -65.060    -26.818     0.077    937.0
# 4   -66.61 -27.33    8.0     202.0    -65.196    -26.926     0.078    915.0
# ..     ...    ...    ...       ...        ...        ...       ...      ...
# 145 -78.67  -6.73   13.0     201.0    -76.155     -6.210     0.047    692.0
# 146 -75.09 -13.69  100.0     201.0    -54.376    -18.721     0.033    952.0
# 147 -71.31 -14.91   33.0     201.0    -63.587    -15.172     0.057    998.0
# 148 -70.61 -17.25   57.0     201.0    -56.905    -17.477     0.036   1202.0
# 149 -76.13 -11.60    8.0     201.0    -74.670    -11.184     0.043    674.0
#
#      trench_lon  trench_lat  ...  trench_abs_paral  subducting_abs_rate  \
# 0        -70.50      -26.45  ...              0.74                -9.04
# 1        -48.48      -31.97  ...             -0.05                -4.28
# 2        -70.12      -29.79  ...              0.12                -9.37
# 3        -69.97      -26.30  ...              0.72                -9.04
# 4        -70.15      -26.35  ...              0.73                -9.04
# ..          ...         ...  ...               ...                  ...
# 145      -78.64       -7.27  ...             -1.18                -8.69
# 146      -55.74      -20.07  ...             -2.35                -8.58
# 147      -66.03      -17.43  ...             -2.52                -8.06
# 148      -58.51      -18.90  ...             -0.60                 0.81
# 149      -76.84      -12.48  ...             -0.57                -8.80
#
#      subducting_abs_angle  subducting_abs_ortho  subducting_abs_paral  \
# 0                  -13.09                  8.81                 -2.05
# 1                  -10.39                  4.21                 -0.77
# 2                  -15.11                  9.05                 -2.44
# 3                  -13.05                  8.81                 -2.04
# 4                  -13.07                  8.81                 -2.04
# ..                    ...                   ...                   ...
# 145                 16.04                  8.35                  2.40
# 146                 -3.67                  8.57                 -0.55
# 147                 50.56                  5.12                  6.22
# 148                130.18                 -0.52                  0.62
# 149                 27.52                  7.81                  4.07
#
#      seafloor_age  subduction_volume_km3y  carbonate_sediment_thickness  \
# 0           60.37                    0.18                         28.71
# 1           18.69                    0.04                          0.00
# 2           63.65                    0.21                         16.71
# 3           73.67                    0.20                         20.21
# 4           71.03                    0.20                         17.86
# ..            ...                     ...                           ...
# 145         56.64                    0.18                         43.39
# 146         39.34                    0.11                         11.59
# 147         98.17                    0.14                         12.99
# 148         72.58                    0.02                           NaN
# 149         48.40                    0.15                         35.85
#
#      total_sediment_thick  ocean_crust_carb_percent
# 0                  131.95                      2.15
# 1                   74.44                      2.12
# 2                  135.08                      2.24
# 3                  143.37                      2.45
# 4                  141.67                      2.45
# ..                    ...                       ...
# 145                128.00                      2.10
# 146                 89.39                      2.18
# 147                156.17                      2.56
# 148                142.63                      2.47
# 149                118.03                      2.14
#
# [150 rows x 33 columns]

# %%
deposits_file_name = 'case_AREPS/coreg_output_clean/SA/negative_deposits.csv'
#map_extent = [-180, -80, 0, 85], #North America
map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-85, -29, -55, 15])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Volcanic Rocks South America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

print("Here are the negative deposits from South America...")
display(data)
# Out:
# Here are the negative deposits from South America...
#         lon     lat   age  plate_id  recon_lon  recon_lat  distance  sub_idx  \
# 0   -72.970 -45.900   0.0     283.0    -72.970    -45.900     0.031    750.0
# 1   -72.950 -40.710   0.0     283.0    -72.950    -40.710     0.028    781.0
# 2   -72.950 -41.870   0.0     283.0    -72.950    -41.870     0.029    769.0
# 3   -72.739 -46.179   0.0   28800.0    -72.739    -46.179     0.034    747.0
# 4   -72.700 -46.165   0.0   28800.0    -72.700    -46.165     0.035    747.0
# ..      ...     ...   ...       ...        ...        ...       ...      ...
# 601 -70.660 -33.385  27.0    2901.0    -64.302    -33.301     0.030    890.0
# 602 -70.660 -33.385  28.0    2901.0    -64.017    -33.353     0.030    862.0
# 603 -69.999 -42.054  30.0     283.0    -62.598    -42.117     0.068    868.0
# 604 -69.500 -42.500  30.0     283.0    -62.088    -42.556     0.075    866.0
# 605 -70.660 -33.385  31.0    2901.0    -63.154    -33.516     0.030   1031.0
#
#      trench_lon  trench_lat  ...  trench_abs_paral  subducting_abs_rate  \
# 0        -75.55      -45.84  ...              0.67                -1.26
# 1        -75.01      -40.51  ...              0.78                -7.29
# 2        -75.19      -41.68  ...              0.77                -7.28
# 3        -75.56      -46.00  ...              0.67                -1.26
# 4        -75.56      -46.00  ...              0.67                -1.26
# ..          ...         ...  ...               ...                  ...
# 601      -66.35      -33.03  ...             -0.35                -8.80
# 602      -66.06      -33.08  ...             -0.36                -8.79
# 603      -67.81      -41.82  ...             -0.44                -7.76
# 604      -67.85      -42.16  ...             -0.44                -7.72
# 605      -65.21      -33.25  ...             -0.43                -8.94
#
#      subducting_abs_angle  subducting_abs_ortho  subducting_abs_paral  \
# 0                   48.09                  0.84                  0.94
# 1                  -15.40                  7.03                 -1.94
# 2                  -15.07                  7.03                 -1.89
# 3                   48.15                  0.84                  0.94
# 4                   48.15                  0.84                  0.94
# ..                    ...                   ...                   ...
# 601                -29.87                  7.63                 -4.38
# 602                -30.03                  7.61                 -4.40
# 603                -35.83                  6.29                 -4.55
# 604                -36.06                  6.24                 -4.55
# 605                -30.73                  7.69                 -4.57
#
#      seafloor_age  subduction_volume_km3y  carbonate_sediment_thickness  \
# 0            0.79                    0.00                         20.17
# 1           20.52                    0.07                         99.90
# 2           14.73                    0.06                         89.47
# 3            0.79                    0.00                         20.17
# 4            0.79                    0.00                         20.17
# ..            ...                     ...                           ...
# 601         53.35                    0.17                          5.57
# 602         52.37                    0.17                         11.55
# 603         36.70                    0.11                         23.26
# 604         36.70                    0.11                         22.10
# 605         49.50                    0.17                          5.88
#
#      total_sediment_thick  ocean_crust_carb_percent
# 0                   64.53                      0.86
# 1                   73.42                      1.49
# 2                   64.84                      1.42
# 3                   64.53                      0.86
# 4                   64.53                      0.86
# ..                    ...                       ...
# 601                124.04                      2.24
# 602                122.85                      2.24
# 603                100.88                      2.00
# 604                100.88                      2.00
# 605                119.27                      2.21
#
# [606 rows x 33 columns]
