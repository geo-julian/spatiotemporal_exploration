# %%
import pandas as pd
import shapefile, csv, math
from shapely.geometry import Point
import scipy.spatial
import numpy as np

import pygplates
from parameters import parameters as param

# input: degrees between two points on sphere
# output: straight distance between the two points (assume the earth radius is 1)
# to get the kilometers, use the return value to multiply by the real earth radius
def degree_to_straight_distance(degree):
    return math.sin(math.radians(degree)) / math.sin(math.radians(90 - degree/2.))

data=pd.read_csv("EarthChem_all.csv", sep=',', skipinitialspace=True)
c='ND'
#print(data.columns.values)
a=data.columns.get_loc(c)
df=data.iloc[:,[6,7,10,a]] 
#6,7,10 are the default column numbers for Long, Lat and Age. Please check their position beforehand 
df=df[(df!=0).all(1)]
df=df.dropna()
#print(len(df))

# build the tree of the trench points
t=0
trench_points_filename = param['convergence_data_dir'] + param['convergence_data_filename_prefix'] +\
    '_{:0.2f}'.format(t) + "." + param['convergence_data_filename_ext']
data=np.loadtxt(trench_points_filename)
print(trench_points_filename)

points_3d = [pygplates.PointOnSphere((row[1],row[0])).to_xyz() for row in data]
points_tree = scipy.spatial.cKDTree(points_3d)

data_index=[]
index_count=-1
candidates=[]
for index, row in df.iterrows():
    index_count+=1
    try:
        candidates.append(pygplates.PointOnSphere((row[0], row[1])).to_xyz())#lat, lon
        data_index.append(index_count)
    except pygplates.InvalidLatLonError:
        print('invalid lat or lon: ',row)
        continue

region = 1 #degrees
dists, indices = points_tree.query(
            candidates, k=1, distance_upper_bound=degree_to_straight_distance(region))

result_index = np.array(data_index)[indices<len(points_3d)]
print(len(result_index))

# create a point shapefile
sf = shapefile.Writer(shapefile.POINT)
# for every record there must be a corresponding geometry.
sf.autoBalance = 1

# create the field names and data type for each.
sf.field("AGE", "N")
sf.field(c, "C")
#"C": Characters, text.
#"N": Numbers, with or without decimals.
#"F": Floats (same as "N").
#"L": Logical, for boolean True/False values.
#"D": Dates.
#"M": Memo, has no meaning within a GIS and is part of the xbase spec instead.

for idx in result_index:
    # create the point geometry
    sf.point(df.iloc[idx][1],df.iloc[idx][0]) #lon lat
    print(df.iloc[idx][1],df.iloc[idx][0])
    # add attribute data
    sf.record(df.iloc[idx][2], df.iloc[idx][3])

sf.save('out.shp')

df.iloc[result_index].to_csv("out.csv",index=False,float_format='%.4f')
# Out:
# ./convergence_data/subStats_0.00.csv
# ('invalid lat or lon: ', LATITUDE       49.24
# LONGITUDE   -1295.00
# AGE            44.25
# ND             12.60
# Name: 23956, dtype: float64)
# ('invalid lat or lon: ', LATITUDE     110.7560
# LONGITUDE    -38.0775
# AGE           27.0000
# ND            30.9000
# Name: 33160, dtype: float64)
# ('invalid lat or lon: ', LATITUDE     110.8040
# LONGITUDE    -38.0939
# AGE           27.0000
# ND            22.1000
# Name: 33165, dtype: float64)
# ('invalid lat or lon: ', LATITUDE     110.8040
# LONGITUDE    -38.0939
# AGE           27.0000
# ND            21.3000
# Name: 33171, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.668
# LONGITUDE    -37.510
# AGE           28.500
# ND            31.000
# Name: 41450, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            30.000
# Name: 41451, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            30.000
# Name: 41454, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            29.000
# Name: 41456, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            30.000
# Name: 41458, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            27.000
# Name: 41460, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.778
# LONGITUDE    -37.543
# AGE           28.500
# ND            27.000
# Name: 41461, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            27.000
# Name: 41463, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.478
# AGE           28.500
# ND            25.000
# Name: 41466, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.667
# LONGITUDE    -38.096
# AGE           28.500
# ND            27.000
# Name: 41467, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.056
# LONGITUDE    -37.536
# AGE           28.500
# ND            27.000
# Name: 41469, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.793
# LONGITUDE    -37.574
# AGE           27.930
# ND            27.000
# Name: 41471, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.782
# LONGITUDE    -37.561
# AGE           27.930
# ND            28.000
# Name: 41472, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.871
# LONGITUDE    -37.543
# AGE           27.930
# ND            26.000
# Name: 41475, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.067
# LONGITUDE    -37.444
# AGE           27.930
# ND            28.000
# Name: 41476, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            27.000
# Name: 41478, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            27.000
# Name: 41481, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            28.000
# Name: 41482, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            29.000
# Name: 41484, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            26.000
# Name: 41487, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            31.200
# Name: 41488, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            31.000
# Name: 41489, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            32.000
# Name: 41491, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            31.500
# Name: 41492, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            27.000
# Name: 41494, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.571
# AGE           27.930
# ND            27.000
# Name: 41497, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.758
# LONGITUDE    -37.569
# AGE           27.930
# ND            26.000
# Name: 41498, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.774
# LONGITUDE    -37.547
# AGE           27.930
# ND            26.000
# Name: 41500, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.771
# LONGITUDE    -37.550
# AGE           27.930
# ND            27.000
# Name: 41502, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.793
# LONGITUDE    -37.557
# AGE           27.930
# ND            30.000
# Name: 41504, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.793
# LONGITUDE    -37.557
# AGE           27.930
# ND            30.500
# Name: 41506, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.793
# LONGITUDE    -37.540
# AGE           27.930
# ND            26.000
# Name: 41507, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.874
# LONGITUDE    -37.629
# AGE           27.930
# ND            32.000
# Name: 41510, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.896
# LONGITUDE    -37.601
# AGE           27.930
# ND            29.000
# Name: 41512, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.870
# LONGITUDE    -37.488
# AGE           27.930
# ND            33.400
# Name: 41513, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -106.870
# LONGITUDE    -37.488
# AGE           27.930
# ND            26.000
# Name: 41515, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.003
# LONGITUDE    -37.464
# AGE           27.930
# ND            27.000
# Name: 41516, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            28.000
# Name: 41518, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            27.000
# Name: 41520, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            28.000
# Name: 41523, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            31.000
# Name: 41524, dtype: float64)
# ('invalid lat or lon: ', LATITUDE    -107.044
# LONGITUDE    -37.438
# AGE           27.930
# ND            26.000
# Name: 41526, dtype: float64)
# ('invalid lat or lon: ', LATITUDE     -49.2353
# LONGITUDE    943.6670
# AGE           32.7500
# ND            80.6000
# Name: 146855, dtype: float64)
# ('invalid lat or lon: ', LATITUDE       66.27
# LONGITUDE    3304.00
# AGE          2050.00
# ND              9.91
# Name: 181736, dtype: float64)
# ('invalid lat or lon: ', LATITUDE       66.27
# LONGITUDE    3304.00
# AGE          2050.00
# ND             17.13
# Name: 181737, dtype: float64)
# 4022
# (-104.88, 20.49)
# (-104.73, 21.43)
# (-104.96, 21.47)
# (-104.909, 20.555)
# (-104.92, 20.57)
# (-104.92, 20.57)
# (-104.92, 20.57)
# (-104.92, 20.57)
# (-104.888, 20.568)
# (-104.92, 20.57)
# (-104.92, 20.57)
# (-104.863, 20.55)
# (-104.896, 20.545)
# (-104.775, 20.575)
# (-104.856, 20.6)
# (-127.372, 50.166)
# (-127.09, 50.03)
# (-127.97, 50.71)
# (-127.83, 50.65)
# (-126.542, 48.313)
# (-105.094, 21.685)
# (-105.28, 21.54)
# (-105.26, 21.515)
# (-105.22, 21.15)
# (-105.16, 21.03)
# (-105.16, 21.07)
# (-105.2, 21.16)
# (-105.2, 21.17)
# (-105.15, 21.28)
# (-105.16, 21.23)
# (-105.17, 21.43)
# (-105.11, 21.48)
# (-105.04, 21.21)
# (-105.04, 21.21)
# (-104.95, 21.12)
# (-105.08, 21.5)
# (-105.16, 21.62)
# (-105.17, 21.4)
# (-105.17, 21.4)
# (-105.17, 21.4)
# (-105.18, 21.4)
# (-105.2, 21.42)
# (-105.03, 21.64)
# (-105.03, 21.64)
# (-104.75, 21.15)
# (-105.05, 21.01)
# (-105.07, 20.8)
# (-105.09, 20.97)
# (-104.97, 21.48)
# (-105.26, 21.62)
# (-104.87, 21.14)
# (-104.93, 21.08)
# (-104.82, 21.22)
# (-104.89, 20.96)
# (-104.82, 20.51)
# (-104.77, 20.55)
# (-104.79, 20.544)
# (-104.856, 20.438)
# (-104.857, 20.468)
# (-104.76, 20.555)
# (-104.939, 21.52)
# (-104.939, 21.52)
# (-104.966, 21.519)
# (-104.983, 21.517)
# (-104.977, 21.467)
# (-104.939, 21.52)
# (-104.939, 21.52)
# (-104.939, 21.52)
# (-105.109, 21.479)
# (-104.974, 21.472)
# (-104.926, 21.513)
# (-104.978, 21.519)
# (-104.939, 21.52)
# (-105.28, 21.02)
# (-105.265, 21.023000000000003)
# (-105.04, 21.67)
# (-104.758, 21.142)
# (-104.761, 21.05)
# (-104.764, 21.054)
# (-104.796, 21.089)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (-173.92, -15.87)
# (-173.92, -15.87)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (133.17, 29.75)
# (138.5, 34.5)
# (138.5, 34.5)
# (138.5, 34.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (143.0, 38.5)
# (142.23, 27.1)
# (142.23, 27.1)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (141.314, 30.861)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (119.12, -9.55)
# (141.314, 30.861)
# (141.738, 30.9082)
# (141.314, 30.861)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.227, 31.875)
# (141.227, 31.875)
# (141.314, 30.861)
# (141.738, 30.9082)
# (141.314, 30.861)
# (141.738, 30.9082)
# (141.227, 31.875)
# (141.227, 31.875)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.738, 30.9082)
# (141.314, 30.861)
# (141.227, 31.875)
# (141.227, 31.875)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (-84.0, 9.5)
# (-84.0, 9.5)
# (-84.0, 9.5)
# (-84.5, 9.5)
# (-84.5, 9.5)
# (-84.5, 9.5)
# (-84.5, 9.5)
# (-84.5, 9.5)
# (-84.5, 9.5)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (25.45, 36.4)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.9, 20.25)
# (121.95, 19.5)
# (121.95, 19.5)
# (122.2, 18.13)
# (122.2, 18.13)
# (122.2, 18.13)
# (121.5, 22.1)
# (121.5, 22.1)
# (121.5, 22.1)
# (121.5, 22.1)
# (121.5, 22.6)
# (121.5, 22.6)
# (121.5, 22.6)
# (121.5, 22.6)
# (-71.6, -32.8)
# (-71.6, -32.8)
# (-71.6, -32.8)
# (-71.6, -32.8)
# (169.7, -20.15)
# (169.27, -19.53)
# (168.1, -17.5)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (150.98, -5.45)
# (150.98, -5.45)
# (150.98, -5.45)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.74, 50.95)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-167.77700000000004, 51.2011)
# (-80.7, -1.0)
# (-80.7, -1.3)
# (-80.9, -2.3)
# (-80.7, -1.3)
# (-80.7, -1.3)
# (-80.8, -1.7)
# (-80.5, -1.0)
# (-80.5, -1.0)
# (-70.333, -23.7239)
# (-70.333, -23.7239)
# (-70.333, -23.7239)
# (-70.333, -23.7239)
# (-70.333, -23.7239)
# (-70.333, -23.7239)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.3212, -23.625)
# (-70.4308, -23.7678)
# (-70.4308, -23.7678)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.3145, -23.5202)
# (-70.2399, -22.7077)
# (-70.2399, -22.7077)
# (-70.2399, -22.7077)
# (-70.2399, -22.7077)
# (-70.2399, -22.7077)
# (-70.2399, -22.7077)
# (-70.1858, -22.1218)
# (-70.1858, -22.1218)
# (-70.1858, -22.1218)
# (-70.1858, -22.1218)
# (-70.1858, -22.1218)
# (11.366, 38.55)
# (11.366, 38.55)
# (11.366, 38.55)
# (173.13299999999995, -41.4)
# (173.13299999999995, -41.4)
# (173.13299999999995, -41.4)
# (173.13299999999995, -41.4)
# (173.13299999999995, -41.4)
# (173.067, -41.6333)
# (173.067, -41.6333)
# (12.0292, 42.5439)
# (12.0292, 42.5439)
# (11.9986, 42.5383)
# (12.0569, 42.5439)
# (12.5878, 42.0344)
# (12.7075, 42.0906)
# (12.6991, 42.1006)
# (12.6572, 42.175)
# (12.6553, 42.1797)
# (12.6369, 42.1533)
# (12.735, 42.0869)
# (12.66, 42.0814)
# (12.4764, 42.1378)
# (12.4925, 42.0606)
# (12.75, 42.1819)
# (12.5916, 42.2031)
# (12.6419, 42.1761)
# (12.685, 42.1708)
# (12.7028, 42.1531)
# (11.9433, 42.7592)
# (11.9542, 42.7558)
# (11.62, 42.88)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.05, 40.78)
# (13.2789, 41.5367)
# (13.33, 41.57)
# (13.42, 41.57)
# (11.83, 42.63)
# (11.83, 42.63)
# (11.83, 42.63)
# (11.83, 42.63)
# (11.83, 42.63)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (123.669, 5.1448)
# (10.7689, 43.3917)
# (10.7689, 43.3917)
# (10.7394, 43.4361)
# (10.7394, 43.4361)
# (11.95, 42.75)
# (8.8, 47.8)
# (8.82, 47.77)
# (8.83, 47.75)
# (8.22, 47.75)
# (8.75, 47.8)
# (8.75, 47.83)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (27.0, 46.0)
# (27.17, 46.48)
# (19.78, 48.3)
# (21.25, 49.35)
# (21.2, 49.3)
# (21.2, 49.3)
# (21.2, 49.3)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (23.87, 47.7)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (25.4, 36.35)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (11.93, 42.6)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.2, 40.9)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (14.0875, 40.9667)
# (14.0875, 40.9667)
# (13.9789, 40.8031)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (10.53, 43.1)
# (11.765999999999998, 42.9)
# (11.765999999999998, 42.9)
# (11.765999999999998, 42.9)
# (11.765999999999998, 42.9)
# (10.7689, 43.3917)
# (11.93, 42.15)
# (11.93, 42.15)
# (11.93, 42.15)
# (11.93, 42.15)
# (11.93, 42.15)
# (12.1, 42.0)
# (12.13, 42.13)
# (12.13, 42.13)
# (11.93, 42.15)
# (12.1, 42.0)
# (11.93, 42.15)
# (11.93, 42.15)
# (11.93, 42.15)
# (12.13, 42.13)
# (12.13, 42.13)
# (12.13, 42.13)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (8.72, 47.87)
# (8.73, 47.92)
# (8.7, 48.0)
# (8.75, 47.8)
# (8.75, 47.77)
# (140.85, 35.72)
# (140.85, 35.72)
# (140.85, 35.72)
# (140.85, 35.72)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (25.53, 46.08)
# (17.77, 47.6)
# (17.0, 47.2)
# (27.0, 46.0)
# (15.97, 46.76)
# (16.52, 47.5)
# (15.94, 46.85)
# (16.52, 47.5)
# (17.25, 47.55)
# (17.25, 47.55)
# (17.25, 47.55)
# (16.33, 47.6)
# (16.33, 47.6)
# (17.0, 47.2)
# (17.0, 47.2)
# (17.0, 47.2)
# (25.58, 46.45)
# (19.1, 48.52)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.8467, 40.9192)
# (12.8467, 40.9192)
# (12.8467, 40.9192)
# (12.8467, 40.9192)
# (12.8467, 40.9192)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (36.8242, 36.7869)
# (36.83, 36.7825)
# (36.8186, 36.7856)
# (36.4692, 36.6247)
# (37.0383, 36.4842)
# (37.0739, 36.6094)
# (36.8367, 36.7583)
# (36.8147, 36.7789)
# (36.8147, 36.7789)
# (37.2278, 36.1156)
# (37.3294, 36.6264)
# (14.2, 40.9)
# (14.03, 40.78)
# (14.05, 40.78)
# (14.03, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.03, 40.78)
# (14.03, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (8.73, 47.92)
# (21.4008, 42.3989)
# (21.4008, 42.3989)
# (21.4008, 42.3989)
# (21.1167, 43.1167)
# (26.4506, 38.67)
# (39.2478, 37.6628)
# (39.2289, 37.6539)
# (40.1558, 37.9828)
# (39.83, 37.67)
# (36.65, 37.1)
# (37.08, 37.45)
# (37.02, 37.35)
# (37.2, 37.45)
# (36.15, 37.05)
# (36.15, 37.05)
# (36.13, 37.05)
# (36.13, 37.05)
# (36.13, 37.07)
# (36.13, 37.07)
# (36.13, 37.07)
# (36.15, 37.02)
# (36.03, 36.93)
# (35.95, 36.93)
# (36.35, 36.5)
# (36.35, 36.5)
# (36.15, 37.05)
# (36.15, 37.05)
# (36.15, 37.05)
# (36.15, 37.05)
# (36.07, 37.02)
# (36.07, 37.02)
# (36.07, 37.02)
# (36.07, 37.02)
# (36.07, 37.02)
# (36.16, 37.15)
# (36.16, 37.15)
# (36.07, 37.15)
# (36.07, 37.15)
# (36.07, 37.15)
# (36.07, 37.15)
# (39.83, 37.67)
# (39.83, 37.67)
# (39.83, 37.67)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.52, 47.5)
# (16.52, 47.5)
# (16.52, 47.5)
# (15.94, 46.85)
# (15.94, 46.85)
# (15.94, 46.85)
# (17.77, 47.6)
# (17.77, 47.6)
# (17.77, 47.6)
# (17.0, 47.2)
# (27.0, 46.0)
# (27.0, 46.0)
# (27.0, 46.0)
# (26.0, 46.0)
# (26.0, 46.0)
# (25.2, 46.0)
# (13.28, 41.53)
# (14.2, 40.9)
# (13.28, 41.53)
# (13.28, 41.53)
# (13.28, 41.53)
# (13.28, 41.53)
# (13.33, 41.57)
# (37.2742, 37.0361)
# (37.1008, 37.2033)
# (37.2756, 37.2031)
# (37.2756, 37.2031)
# (37.2747, 37.0408)
# (37.2747, 37.0408)
# (37.2747, 37.0408)
# (37.2747, 37.0408)
# (37.2747, 37.0408)
# (37.2747, 37.0408)
# (37.1089, 37.2083)
# (37.1092, 37.2083)
# (37.2675, 37.2072)
# (37.2675, 37.2072)
# (37.2764, 37.2064)
# (37.2767, 37.2064)
# (37.2361, 37.225)
# (37.28, 37.2058)
# (37.2808, 37.1989)
# (37.3003, 37.1892)
# (37.3206, 37.1708)
# (37.3217, 37.1625)
# (37.5019, 37.3642)
# (37.505, 37.3611)
# (37.3417, 37.3244)
# (37.3244, 37.3106)
# (37.3244, 37.3106)
# (37.3208, 37.3136)
# (37.3156, 37.3344)
# (37.3144, 37.3536)
# (37.3181, 37.3769)
# (37.315, 37.39)
# (37.3086, 37.4317)
# (37.3222, 37.4875)
# (37.3992, 37.5719)
# (37.3917, 37.5658)
# (37.3872, 37.5592)
# (37.3847, 37.5611)
# (37.38, 37.5494)
# (37.3783, 37.55)
# (37.3983, 37.5378)
# (37.3586, 37.5425)
# (37.3556, 37.5439)
# (37.3556, 37.5439)
# (16.63, 49.2)
# (16.63, 49.2)
# (16.63, 49.2)
# (16.63, 49.2)
# (16.63, 49.2)
# (16.63, 49.2)
# (-102.42, 18.46)
# (-102.42, 18.46)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (121.9, 20.25)
# (121.9, 20.25)
# (-105.016, 21.6292)
# (-105.04, 21.6767)
# (-105.28, 21.0245)
# (-105.267, 21.0228)
# (-102.34, 17.98)
# (-102.34, 17.98)
# (-102.34, 17.98)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.78, 47.85)
# (7.72, 47.77)
# (7.72, 47.77)
# (38.18, 36.65)
# (40.21, 37.92)
# (40.21, 37.92)
# (17.12, 47.23)
# (27.0, 46.0)
# (19.95, 48.68)
# (19.95, 48.68)
# (13.9, 40.7)
# (14.05, 40.78)
# (14.05, 40.78)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.5845, 41.7586)
# (12.65, 41.73)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (172.52, 52.31)
# (170.76, 52.65)
# (170.76, 52.65)
# (170.76, 52.65)
# (170.76, 52.65)
# (170.76, 52.65)
# (170.76, 52.65)
# (168.55, 53.15)
# (168.55, 53.15)
# (168.55, 53.15)
# (168.55, 53.15)
# (168.55, 53.15)
# (168.13, 53.42)
# (168.13, 53.42)
# (168.13, 53.42)
# (168.13, 53.42)
# (168.13, 53.42)
# (168.13, 53.42)
# (168.13, 53.42)
# (166.93, 53.9)
# (166.93, 53.9)
# (166.93, 53.9)
# (166.93, 53.9)
# (166.93, 53.9)
# (-70.2861, -22.2671)
# (-70.3667, -23.4081)
# (-70.5111, -25.2333)
# (-70.51100000000002, -25.408)
# (-70.547, -25.6917)
# (-70.547, -25.6917)
# (-70.547, -25.6917)
# (-70.547, -25.6917)
# (-70.547, -25.6917)
# (-70.547, -25.6917)
# (-70.4642, -24.9258)
# (-70.4642, -24.9258)
# (-70.5944, -25.875)
# (-70.5944, -25.875)
# (-70.5944, -25.875)
# (-70.5, -25.4667)
# (-70.5, -25.4667)
# (-70.5, -25.4667)
# (-70.5, -25.4667)
# (-70.5, -25.4667)
# (-70.5, -25.4667)
# (-70.4167, -23.8333)
# (-70.4167, -23.8333)
# (-70.4167, -23.8333)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (-70.383, -24.967)
# (142.317, 26.3317)
# (142.317, 26.3317)
# (142.317, 26.3317)
# (142.317, 26.3317)
# (142.317, 26.3317)
# (142.317, 26.3317)
# (168.3, -17.46)
# (-174.92, -21.03)
# (-174.92, -21.03)
# (-174.92, -21.03)
# (-174.92, -21.03)
# (-174.92, -21.03)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (14.0333, 41.0569)
# (13.95, 41.1319)
# (14.05, 40.78)
# (-127.97, 50.71)
# (-127.83, 50.65)
# (-127.09, 50.03)
# (-127.372, 50.166)
# (14.0903, 40.8319)
# (14.0881, 40.8325)
# (14.0083, 40.8592)
# (14.0903, 40.8319)
# (14.0903, 40.8319)
# (14.0881, 40.8325)
# (14.0881, 40.8325)
# (14.0881, 40.8325)
# (14.0881, 40.8325)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (120.35, 15.13)
# (120.35, 15.13)
# (120.35, 15.13)
# (120.35, 15.13)
# (152.5, 46.5)
# (26.9598, 36.7378)
# (26.9573, 36.739)
# (26.9523, 36.6945)
# (26.9507, 36.699)
# (26.9477, 36.7033)
# (26.9717, 36.7228)
# (26.9558, 36.724)
# (26.9567, 36.7257)
# (26.9567, 36.7257)
# (26.9893, 36.7602)
# (26.9893, 36.7602)
# (27.0793, 36.7713)
# (27.0813, 36.7692)
# (26.963, 36.7117)
# (26.9637, 36.711)
# (26.9652, 36.678)
# (27.0195, 36.7687)
# (-90.9328, 12.7168)
# (-90.9328, 12.7168)
# (-90.9328, 12.7168)
# (-90.9328, 12.7168)
# (-90.9328, 12.7168)
# (-90.9447, 12.6705)
# (-90.9437, 12.6825)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (-90.932, 12.7165)
# (49.451, 33.306999999999995)
# (49.5, 33.284)
# (46.688, 33.635)
# (47.88399999999999, 34.537)
# (47.932, 34.596)
# (47.93600000000001, 34.608000000000004)
# (47.949, 34.618)
# (47.895, 34.809)
# (47.878, 34.733000000000004)
# (47.81800000000001, 34.774)
# (47.819, 34.959)
# (54.015, 30.671)
# (46.9925, 35.4211)
# (46.9922, 35.4189)
# (46.9917, 35.4183)
# (47.0603, 35.4972)
# (47.0194, 35.53)
# (46.9589, 35.4614)
# (47.055, 35.4933)
# (47.0986, 35.53)
# (47.0986, 35.5303)
# (46.8589, 35.5975)
# (46.8992, 35.6303)
# (-104.08, 19.38)
# (-104.08, 19.38)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (-152.5, 57.0)
# (25.169, 39.81800000000001)
# (25.168000000000006, 39.813)
# (25.168000000000006, 39.816)
# (25.173, 39.897)
# (25.151, 39.94300000000001)
# (25.166, 39.946)
# (25.157, 39.96)
# (25.297, 39.923)
# (25.297, 39.923)
# (25.31, 39.878)
# (25.297, 39.923)
# (25.294, 39.908)
# (25.315, 39.87300000000001)
# (25.31, 39.878)
# (25.154, 39.965)
# (25.079, 39.861)
# (25.317, 39.867)
# (25.071, 39.924)
# (25.143, 39.909)
# (25.052, 39.941)
# (25.071, 39.924)
# (25.065, 39.851)
# (25.08, 39.917)
# (25.08, 39.917)
# (25.066, 39.853)
# (25.066, 39.853)
# (12.8215, 41.848)
# (12.7531, 41.7068)
# (12.664, 41.8419)
# (12.691, 41.8207)
# (12.7079, 41.8507)
# (12.7273, 41.7988)
# (12.7338, 41.7913)
# (12.7526, 41.8503)
# (12.7749, 41.6747)
# (12.7031, 41.7997)
# (12.7048, 41.7973)
# (12.707, 41.7945)
# (12.7864, 41.7285)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (18.0, 49.55)
# (18.03, 49.53)
# (18.45, 49.73)
# (18.45, 49.73)
# (17.98, 49.57)
# (17.98, 49.57)
# (18.03, 49.57)
# (18.03, 49.57)
# (18.32, 49.75)
# (18.27, 49.68)
# (18.12, 49.55)
# (17.78, 49.08)
# (18.03, 49.57)
# (17.83, 49.5)
# (37.0583, 35.7239)
# (37.0572, 35.7197)
# (36.4069, 35.7561)
# (36.4106, 35.7581)
# (36.4086, 35.7567)
# (36.3606, 35.7611)
# (36.325, 35.7914)
# (36.3958, 35.5961)
# (36.4053, 35.5989)
# (36.2447, 35.0961)
# (36.2092, 35.0928)
# (36.1894, 35.0994)
# (36.8892, 35.6103)
# (36.8892, 35.6103)
# (37.0547, 35.58)
# (40.8606, 36.5386)
# (40.5333, 36.5822)
# (40.4039, 36.6192)
# (40.4119, 36.6603)
# (40.4186, 36.6914)
# (40.5292, 36.9967)
# (41.5836, 37.0208)
# (41.6331, 37.0122)
# (41.7386, 36.9992)
# (41.8067, 36.97)
# (41.8422, 36.9881)
# (42.1231, 37.1208)
# (42.1594, 37.2028)
# (42.195, 37.2822)
# (41.8931, 36.9903)
# (-143.339, 60.3094)
# (-143.339, 60.3094)
# (-143.332, 60.3081)
# (-143.305, 60.3191)
# (-143.305, 60.3241)
# (-143.305, 60.3241)
# (-143.30700000000004, 60.3245)
# (-143.30700000000004, 60.3245)
# (-143.309, 60.3241)
# (-143.309, 60.3243)
# (17.48, 49.7)
# (26.4506, 38.67)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (121.3, 22.97)
# (46.95, 34.82)
# (46.95, 34.82)
# (46.95, 34.82)
# (46.95, 34.82)
# (38.2819, 38.0597)
# (38.2808, 38.0608)
# (38.2789, 38.0603)
# (38.2803, 38.0606)
# (38.2814, 38.0594)
# (38.2756, 38.0594)
# (38.275, 38.0608)
# (37.9892, 38.1578)
# (37.9953, 38.1564)
# (37.9969, 38.1561)
# (38.0, 38.1561)
# (38.0014, 38.1572)
# (37.9908, 38.1617)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (26.0, 39.5)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (27.0, 38.0)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (36.5, 36.8)
# (35.6, 36.95)
# (35.6, 36.95)
# (35.6, 36.95)
# (13.3003, 41.5689)
# (12.3022, 40.5636)
# (12.3022, 40.5636)
# (12.3022, 40.5636)
# (13.3081, 41.5617)
# (13.2108, 41.6253)
# (13.2103, 41.6272)
# (13.3211, 41.6758)
# (13.3222, 41.6858)
# (13.3222, 41.6858)
# (13.3378, 41.6969)
# (13.3169, 41.665)
# (13.3222, 41.6858)
# (13.3256, 41.6661)
# (13.2942, 41.6286)
# (13.2928, 41.5714)
# (13.2831, 41.5797)
# (13.2897, 41.5667)
# (13.2925, 41.5714)
# (13.2831, 41.5797)
# (13.29, 41.5831)
# (13.2889, 41.5642)
# (13.2886, 41.5819)
# (13.2733, 41.5411)
# (13.2781, 41.5394)
# (13.2842, 41.5228)
# (13.2875, 41.5328)
# (13.2875, 41.5328)
# (13.2742, 41.5372)
# (13.3, 41.5)
# (13.275, 41.5408)
# (13.2739, 41.5333)
# (13.3, 41.5)
# (13.2789, 41.5364)
# (13.4369, 41.5689)
# (13.4208, 41.5522)
# (13.4339, 41.5614)
# (13.4083, 41.565)
# (13.4264, 41.5781)
# (13.4133, 41.5778)
# (13.4133, 41.5589)
# (13.4278, 41.5669)
# (13.3628, 41.5281)
# (13.3661, 41.5292)
# (13.35, 41.5536)
# (13.3522, 41.5519)
# (13.3522, 41.5519)
# (13.3578, 41.5339)
# (13.3578, 41.5339)
# (13.32, 41.5397)
# (13.3825, 41.5447)
# (13.3219, 41.5431)
# (13.3183, 41.5447)
# (13.3183, 41.5447)
# (13.3556, 41.5358)
# (13.3556, 41.5358)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (170.0, -43.5)
# (173.0, -41.5)
# (173.0, -41.5)
# (173.0, -41.5)
# (173.0, -41.5)
# (16.98, 49.2)
# (16.98, 49.2)
# (141.738, 30.9082)
# (120.284, 15.25)
# (120.486, 15.1892)
# (120.486, 15.1892)
# (120.289, 15.0511)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-101.55, 17.63)
# (-175.298, -23.3457)
# (-175.298, -23.3457)
# (-175.298, -23.3457)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.4822, 41.8006)
# (12.4822, 41.8028)
# (12.4789, 41.7886)
# (12.4789, 41.7886)
# (12.4789, 41.7886)
# (12.4547, 41.7697)
# (12.7875, 41.9117)
# (12.5325, 41.7614)
# (12.6344, 41.9089)
# (12.5528, 41.7811)
# (12.5528, 41.7811)
# (12.665, 41.9019)
# (12.4867, 41.8178)
# (12.6289, 41.6533)
# (12.5528, 41.7811)
# (12.5528, 41.7811)
# (12.6886, 41.8011)
# (12.7131, 41.7967)
# (12.5528, 41.7811)
# (12.5617, 41.7831)
# (12.6769, 41.9375)
# (12.7067, 41.9)
# (12.7067, 41.9)
# (12.7331, 41.8536)
# (12.7331, 41.8536)
# (12.7331, 41.8536)
# (12.7186, 41.9053)
# (12.6147, 41.7792)
# (12.6128, 41.7683)
# (12.6061, 41.77)
# (12.5967, 41.7583)
# (12.5542, 41.82)
# (12.5831, 41.7911)
# (12.5606, 41.8161)
# (12.5831, 41.7911)
# (12.5831, 41.7911)
# (12.5964, 41.7872)
# (12.5831, 41.7911)
# (12.6947, 41.7158)
# (12.7125, 41.7197)
# (12.7122, 41.7197)
# (12.6789, 41.7525)
# (12.6789, 41.7525)
# (12.65, 41.7533)
# (12.7089, 41.7469)
# (12.7081, 41.7469)
# (12.7233, 41.7692)
# (12.7069, 41.7558)
# (12.6783, 41.7528)
# (12.6783, 41.7528)
# (12.7331, 41.7686)
# (12.7331, 41.7686)
# (12.7331, 41.7686)
# (12.7356, 41.8267)
# (12.7567, 41.8392)
# (12.7547, 41.83)
# (12.7539, 41.8344)
# (12.7078, 41.8281)
# (12.7478, 41.7989)
# (12.7078, 41.8203)
# (12.6786, 41.7981)
# (12.6872, 41.8158)
# (12.6794, 41.8106)
# (12.7258, 41.8092)
# (12.6381, 41.8022)
# (12.7664, 41.7903)
# (12.7158, 41.715)
# (12.7158, 41.715)
# (10.7689, 43.3917)
# (10.7394, 43.4361)
# (10.7394, 43.4361)
# (11.18, 42.95)
# (10.53, 43.1)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.18, 42.95)
# (10.53, 43.1)
# (10.53, 43.1)
# (10.53, 43.1)
# (10.53, 43.1)
# (10.53, 43.1)
# (13.9, 40.7)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (14.0, 38.7)
# (14.0, 38.7)
# (13.2, 38.72)
# (13.2, 38.72)
# (13.2, 38.72)
# (13.2, 38.72)
# (13.2, 38.72)
# (12.9592, 41.3597)
# (14.0511, 40.7897)
# (14.0675, 40.8801)
# (14.1067, 40.8897)
# (14.1067, 40.8897)
# (14.1067, 40.8897)
# (14.1558, 40.8908)
# (14.1892, 40.8525)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2408, 40.8453)
# (14.2633, 40.8764)
# (14.2875, 40.8683)
# (14.2875, 40.8683)
# (14.2875, 40.8683)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (173.602, -42.1199)
# (173.521, -42.1841)
# (173.521, -42.1841)
# (171.958, -43.4866)
# (172.03599999999997, -43.2767)
# (172.03900000000004, -43.2957)
# (171.955, -43.2897)
# (172.158, -43.3718)
# (173.03599999999997, -42.5328)
# (173.05200000000005, -42.5314)
# (172.773, -42.6326)
# (173.14700000000005, -42.5071)
# (173.171, -42.5115)
# (174.03599999999997, -41.882)
# (173.61700000000005, -42.264)
# (173.169, -42.5076)
# (169.815, -43.2319)
# (169.815, -43.2319)
# (179.22799999999995, -39.5608)
# (-178.42, -30.7)
# (-178.42, -30.7)
# (-178.42, -30.7)
# (-178.42, -30.7)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (12.65, 41.73)
# (12.65, 41.73)
# (11.98, 42.63)
# (11.98, 42.63)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (139.52, 34.08)
# (-83.1813, 8.69003)
# (-83.1169, 8.60856)
# (-83.2059, 8.645760000000001)
# (-83.1813, 8.66742)
# (-83.1005, 8.60854)
# (-83.1323, 8.63842)
# (-83.2241, 8.63945)
# (-83.1396, 8.58961)
# (-83.1523, 8.60771)
# (-83.1877, 8.62313)
# (-83.1805, 8.62221)
# (-83.0905, 8.617560000000001)
# (-83.0842, 8.61484)
# (-83.0515, 8.598510000000001)
# (-80.9482, 7.531519999999999)
# (-80.1826, 7.41627)
# (-81.2415, 7.48568)
# (-81.1969, 7.493639999999999)
# (-81.1993, 7.571039999999999)
# (-81.2387, 7.61689)
# (-80.9517, 7.543080000000002)
# (-80.959, 7.53453)
# (-80.8536, 7.5118)
# (-80.8075, 7.482660000000001)
# (-80.8056, 7.50156)
# (-81.7746, 7.62615)
# (-81.8662, 7.468369999999998)
# (-81.6812, 7.50433)
# (-81.6244, 7.69676)
# (-80.4728, 7.3728)
# (-80.5635, 7.36435)
# (-80.6666, 7.42233)
# (-80.2054, 7.42473)
# (-80.4621, 7.51756)
# (-80.5484, 7.310510000000002)
# (-80.6188, 7.4663)
# (-80.4848, 7.447030000000002)
# (-80.2049, 7.43275)
# (-80.2958, 7.45898)
# (-80.2958, 7.45898)
# (-80.5971, 7.53574)
# (-80.3546, 7.333660000000001)
# (-80.3939, 7.4979)
# (-80.339, 7.589360000000001)
# (-80.3232, 7.67815)
# (-80.2927, 7.73539)
# (-81.1977, 7.65212)
# (-81.2025, 7.657089999999998)
# (-81.3713, 7.90222)
# (-80.959, 7.53453)
# (-81.7298, 7.63086)
# (-81.7461, 7.642069999999999)
# (-81.7461, 7.64203)
# (-80.8285, 7.31525)
# (-80.4539, 7.5241)
# (-80.6382, 7.776389999999999)
# (-80.6061, 7.729139999999999)
# (-80.0, 7.47245)
# (-80.0014, 7.47265)
# (-80.0023, 7.473210000000001)
# (-80.339, 7.589360000000001)
# (-80.3513, 7.6154199999999985)
# (-80.3513, 7.6154199999999985)
# (-80.6464, 7.64399)
# (-81.1719, 7.780089999999999)
# (-81.3677, 7.98278)
# (-80.8731, 7.561739999999999)
# (-80.7942, 7.513089999999999)
# (-81.6079, 7.364689999999999)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (120.38, 23.07)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (173.47, -41.9)
# (168.6, 54.0)
# (168.6, 54.0)
# (168.6, 54.0)
# (168.6, 54.0)
# (168.6, 54.0)
# (21.71, 42.26)
# (7.7, 45.67)
# (7.7, 45.67)
# (7.7, 45.67)
# (7.82, 45.78)
# (7.82, 45.78)
# (8.05, 45.57)
# (7.85, 45.68)
# (9.8139, 43.008)
# (10.7394, 43.4361)
# (12.1775, 42.4028)
# (12.25, 42.3)
# (12.25, 42.3)
# (12.25, 42.3)
# (11.7658, 42.8983)
# (7.95, 45.78)
# (7.85, 45.68)
# (7.85, 45.68)
# (8.4, 46.4)
# (7.95, 45.7)
# (7.7, 45.67)
# (7.7, 45.67)
# (7.73, 45.83)
# (3.89, 36.92)
# (3.89, 36.92)
# (3.72, 36.88)
# (3.72, 36.88)
# (3.72, 36.88)
# (3.55, 36.73)
# (3.55, 36.73)
# (3.55, 36.73)
# (3.6, 36.79)
# (3.6, 36.79)
# (3.6, 36.79)
# (3.6, 36.79)
# (3.55, 36.73)
# (3.55, 36.73)
# (3.6, 36.79)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (171.49900000000005, -41.785)
# (-178.53099999999995, -36.0005)
# (-178.53099999999995, -36.0005)
# (-178.53099999999995, -36.0005)
# (-178.53099999999995, -36.0005)
# (-178.47799999999995, -36.0438)
# (-178.137, -36.3853)
# (-178.137, -36.3853)
# (-178.287, -36.0242)
# (-179.892, -39.4186)
# (-178.833, -36.3124)
# (-178.826, -36.2819)
# (-178.12099999999995, -36.3933)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.33, 47.6)
# (16.52, 47.5)
# (-82.9452, 8.8498)
# (-82.9178, 8.6248)
# (-82.874, 8.14)
# (-82.694, 8.529)
# (-81.732, 8.073)
# (-82.04700000000003, 8.28)
# (-81.791, 8.241)
# (-105.879, 21.8436)
# (-105.879, 21.8436)
# (-105.882, 21.85)
# (-105.888, 21.8519)
# (-105.884, 21.8463)
# (-105.885, 21.8491)
# (-105.889, 21.8492)
# (-105.888, 21.848000000000006)
# (-105.886, 21.8433)
# (-105.886, 21.8445)
# (-103.601, 19.2769)
# (36.3119, 35.7711)
# (36.3392, 35.8283)
# (36.3197, 35.7758)
# (36.3581, 35.7672)
# (36.3581, 35.7672)
# (36.3581, 35.7672)
# (36.3564, 35.7694)
# (36.3564, 35.7694)
# (36.3564, 35.7694)
# (36.3939, 35.7717)
# (36.4072, 35.7611)
# (36.3958, 35.8044)
# (36.4153, 35.7428)
# (36.3647, 35.7725)
# (36.405, 35.7136)
# (36.4311, 35.7319)
# (36.4814, 35.7317)
# (36.4839, 35.7297)
# (36.3931, 35.63)
# (36.3881, 35.6494)
# (36.4078, 35.6592)
# (36.4175, 35.6414)
# (36.5094, 35.6072)
# (36.5397, 35.6067)
# (36.5511, 35.5772)
# (36.4664, 35.5781)
# (36.4, 35.6081)
# (36.4, 35.6081)
# (36.4014, 35.6078)
# (-175.804, -26.8193)
# (-80.6035, 7.23183)
# (-80.5632, 7.24338)
# (-80.6194, 7.26116)
# (-80.5356, 7.266960000000001)
# (-80.5451, 7.2805300000000015)
# (-80.5388, 7.272839999999999)
# (-80.9021, 7.46748)
# (-80.9174, 7.43388)
# (-80.9052, 7.23539)
# (-80.7485, 7.2133)
# (-80.8522, 7.21335)
# (-80.9175, 7.43381)
# (-80.9274, 7.42513)
# (-80.9274, 7.42513)
# (-80.9313, 7.418889999999998)
# (-80.8976, 7.3296899999999985)
# (-80.9033, 7.32485)
# ...
# (150.98, -5.45)
# (150.98, -5.45)
# (150.98, -5.45)
# (150.98, -5.45)
# (152.18, -7.35)
# (152.18, -7.35)
# (152.18, -7.35)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (11.9394, 42.5097)
# (11.9222, 42.4742)
# (12.0594, 42.5081)
# (11.9892, 42.5114)
# (11.9903, 42.4267)
# (11.9636, 42.5019)
# (11.9731, 42.4725)
# (11.9881, 42.5064)
# (11.9494, 42.5136)
# (11.9403, 42.5097)
# (11.9353, 42.5078)
# (12.0608, 42.4833)
# (12.0458, 42.5169)
# (11.9769, 42.5092)
# (11.9489, 42.5322)
# (12.0369, 42.4761)
# (11.9167, 42.4953)
# (11.9456, 42.7519)
# (11.9456, 42.7519)
# (11.9456, 42.7519)
# (11.95, 42.7497)
# (11.95, 42.7497)
# (11.9447, 42.7556)
# (138.7, 34.5)
# (138.7, 34.5)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (10.53, 43.1)
# (10.53, 43.1)
# (10.53, 43.1)
# (10.53, 43.1)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.18, 42.95)
# (11.62, 42.88)
# (11.62, 42.88)
# (11.62, 42.88)
# (11.62, 42.88)
# (11.62, 42.88)
# (11.62, 42.88)
# (11.62, 42.88)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (12.65, 41.73)
# (157.09, -8.19)
# (157.09, -8.19)
# (156.97, -7.89)
# (156.97, -7.89)
# (156.97, -7.89)
# (156.97, -7.89)
# (156.97, -7.89)
# (13.28, 41.53)
# (13.33, 41.57)
# (13.33, 41.57)
# (13.33, 41.57)
# (13.28, 41.53)
# (13.28, 41.53)
# (13.33, 41.57)
# (139.5, 34.15)
# (13.4247, 41.5769)
# (13.42, 41.57)
# (13.42, 41.57)
# (13.42, 41.57)
# (13.42, 41.57)
# (13.2972, 41.5678)
# (11.83, 42.63)
# (11.83, 42.63)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (13.43, 40.8)
# (13.43, 40.8)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (13.43, 40.8)
# (13.43, 40.8)
# (13.43, 40.8)
# (147.599, 17.669)
# (147.599, 17.669)
# (147.599, 17.669)
# (8.75, 47.77)
# (-173.92, -15.87)
# (-173.92, -15.87)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (-177.87, -29.25)
# (155.75, -7.08)
# (156.58, -7.75)
# (156.58, -7.75)
# (156.58, -7.75)
# (156.58, -7.75)
# (156.58, -7.75)
# (157.8, -8.38)
# (156.97, -7.89)
# (156.97, -7.89)
# (142.3, 27.3)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (139.02, 35.22)
# (11.83, 42.63)
# (11.83, 42.63)
# (11.83, 42.63)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (12.65, 41.73)
# (16.33, 47.6)
# (16.33, 47.6)
# (24.3, 38.7)
# (24.57, 38.92)
# (24.57, 38.92)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (139.42, 34.75)
# (138.5, 34.5)
# (139.29, 34.4)
# (13.5967, 40.8494)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.03, 40.78)
# (-86.0, 10.0)
# (-84.5, 9.5)
# (-81.0437, 6.122999999999998)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (13.95, 41.1319)
# (14.0, 40.76)
# (14.0, 40.76)
# (14.0, 40.76)
# (13.43, 40.8)
# (13.43, 40.8)
# (13.43, 40.8)
# (13.43, 40.8)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.05, 40.78)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (14.2, 40.9)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (17.0, 47.2)
# (15.92, 46.93)
# (125.07, 1.47)
# (125.07, 1.47)
# (125.07, 1.47)
# (124.72, 1.63)
# (124.72, 1.63)
# (124.72, 1.63)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.95, 40.92)
# (12.8467, 40.9192)
# (12.8467, 40.9192)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.9927, 39.728)
# (12.95, 40.92)
# (21.79, 42.15)
# (21.81, 42.17)
# (21.81, 42.17)
# (169.7, -20.15)
# (169.27, -19.53)
# (168.1, -17.5)
# (13.9, 40.7)
# (13.9, 40.7)
# (155.18, -6.17)
# (121.23, 13.5)
# (26.1, 38.4)
# (26.1, 38.4)
# (21.9403, 43.895)
# (21.9403, 43.895)
# (21.9403, 43.895)
# (21.9403, 43.895)
# (21.7136, 42.2572)
# (21.7136, 42.2572)
# (21.7665, 42.2703)
# (21.8711, 43.6433)
# (21.8711, 43.6433)
# (21.8711, 43.6433)
# (13.28, 41.53)
# (-104.92, 20.5417)
# (-104.92, 20.5417)
# (-104.914, 20.5555)
# (-104.914, 20.5555)
# (-104.889, 20.7337)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (20.4, 49.42)
# (11.765999999999998, 42.9)
# (11.765999999999998, 42.9)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (11.6322, 42.9031)
# (11.5598, 42.8867)
# (139.0, 35.0)
# (-70.2475, -22.5186)
# (-70.1047, -22.1047)
# (-73.2625, -16.3917)
# (-83.2715, 9.0907)
# (-82.9452, 8.8498)
# (-82.9178, 8.6248)
# (-82.87700000000002, 8.184)
# (-82.71, 8.47)
# (-82.238, 7.47)
# (-81.732, 8.073)
# (-82.0377, 8.2742)
# (-82.0377, 8.2742)
# (-172.898, -14.09)
# (-172.898, -14.09)
# (-172.898, -14.09)
# (-172.898, -14.09)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (13.9, 40.7)
# (-90.9328, 12.7168)
# (-90.932, 12.7165)
# (145.06, -4.1)
# (145.06, -4.1)
# (121.0, 20.5)
# (121.0, 20.5)
# (14.3, 40.85)
# (14.3, 40.85)
# (14.3, 40.85)
# (13.3019, 41.5672)
# (13.3081, 41.5617)
# (13.2106, 41.6261)
# (13.3222, 41.6858)
# (13.2942, 41.6286)
# (13.2928, 41.5714)
# (13.3097, 41.5167)
# (13.2733, 41.5389)
# (13.4139, 41.555)
# (13.4447, 41.5661)
# (13.4, 41.5)
# (13.35, 41.5536)
# (13.3558, 41.5264)
# (13.3583, 41.5603)
# (13.3556, 41.5358)
# (-104.926, 20.8038)
# (-104.805, 20.7893)
# (-104.89, 20.5707)
# (-104.881, 20.865)
# (9.8431, 43.0506)
# (9.8067, 43.0311)
# (9.8139, 43.008)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (10.17, 42.77)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (39.0, 37.0)
# (7.7, 45.67)
# (7.82, 45.78)
# (7.82, 45.78)
# (21.71, 42.26)
# (21.71, 42.26)
# (7.95, 45.7)
# (7.95, 45.7)
# (7.85, 45.68)
# (7.85, 45.68)
# (136.0, 33.3)
# (136.0, 33.3)
# (136.0, 33.3)
# (135.8, 33.1)
# (135.8, 33.1)
# (135.8, 33.1)
# (168.6, 54.0)
# (168.6, 54.0)
# (168.6, 54.0)
# (-126.542, 48.313)
# (-129.5, 49.24)
# (11.61, 42.8917)
# (25.35, 47.0833)
# (25.35, 47.0833)
# (25.4, 46.9667)
# (25.4, 46.9667)
# (124.7, 0.85)
# (124.7, 0.85)
# (124.7, 0.85)
# (124.9, 1.3167)
# (124.9, 1.3167)
# (124.9, 1.3167)
# (146.542, 19.632)
# (146.542, 19.632)
# (146.542, 19.632)
# (146.542, 19.632)
# (-78.32, 3.0)
# (-78.32, 3.0)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.227, 31.8742)
# (141.314, 30.861)
# (141.314, 30.861)
# (120.35, 15.13)
# (120.35, 15.13)
# (120.35, 15.13)
# (120.35, 15.13)
# (120.322, 15.168)
# (120.323, 15.1667)
# (120.322, 15.168)
# (120.322, 15.168)
# (120.322, 15.168)
# (120.325, 15.1633)
# (120.325, 15.1633)
# (120.308, 15.1111)
# (120.486, 15.1892)
# (120.324, 15.1936)
# (120.324, 15.1936)
# (120.324, 15.1936)
# (120.289, 15.0511)
# (120.289, 15.0511)
# (120.486, 15.1892)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.289, 15.0511)
# (120.486, 15.1892)
# (166.673, -16.0933)
# (166.673, -16.0933)
# (166.673, -16.0933)
# (152.18, -7.35)
# (152.18, -7.35)
# (152.18, -7.35)
# (-78.32, 3.0)
# (-175.298, -23.3457)
# (-175.298, -23.3457)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (144.67, 13.5)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (141.314, 30.861)
# (156.97, -7.89)
# (156.97, -7.89)
# (156.97, -7.89)
# (156.97, -7.89)
# (144.67, 13.5)
# (142.3, 27.3)
# (146.934, 17.8642)
# (144.67, 13.5)
# (134.5, 7.5)
# (134.5, 7.5)
# (120.15, 14.9)
# (124.651, 15.8185)
# (123.669, 5.1448)
# (-124.25, 40.6167)
# (-124.0, 40.75)
# (-124.247, 42.7583)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-147.847, 60.3333)
# (-126.762, 42.7567)
# (-126.888, 42.4733)
# (120.372, 15.0511)
# (120.034, 15.0833)
# (120.486, 15.1892)
# (120.486, 15.1892)
# (120.353, 15.2275)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.574, 15.1936)
# (120.372, 15.0511)
# (120.372, 15.0511)
# (120.372, 15.0511)
# (120.486, 15.1892)
# (120.486, 15.1892)
# (120.367, 15.15)
# (120.367, 15.15)
# (120.367, 15.1333)
# (120.367, 15.1333)
# (120.322, 15.1681)
# (120.322, 15.1681)
# (120.322, 15.1681)
# (120.324, 15.1633)
# (120.324, 15.1633)
# (120.308, 15.0778)
# (120.506, 15.1883)
# (120.483, 15.1322)
# (120.483, 15.1322)
# (120.483, 15.1322)
# (120.367, 15.2667)
# (120.367, 15.2667)
# (120.367, 15.2667)
# (120.482, 15.1819)
# (120.497, 15.1736)
# (120.5, 15.1833)
# (120.5, 15.1833)
# (120.35, 15.15)
# (120.35, 15.15)
# (120.35, 15.15)
# (120.35, 15.15)
# (9.85, 46.0333)
# (9.58333, 46.0333)
# (9.86667, 46.0333)
# (9.81667, 46.05)
# (9.81667, 46.05)
# (9.81667, 46.05)
# (9.86667, 46.0333)
# (9.86667, 46.05)
# (9.85, 46.0333)
# (9.6, 46.0333)
# (9.6, 46.0333)
# (9.86667, 46.0333)
# (9.6, 46.0333)
# (9.6, 46.0333)
# (9.86667, 46.0333)
# (9.86667, 46.0333)
# (9.86667, 46.0333)
# (9.86667, 46.0333)
# (9.85, 46.0333)
# (9.86667, 46.0333)
# (9.86667, 46.0333)
# (9.81667, 46.05)
# (9.81667, 46.05)
# (9.81667, 46.05)
# (9.6, 46.0333)
# (-76.7967, -13.4964)
# (-76.7981, -13.4953)
# (-76.7981, -13.4953)
# (-76.9236, -13.5078)
# (-76.9236, -13.5078)
# (-76.9081, -13.5111)
# (-76.9081, -13.5111)
# (-76.9236, -13.5078)
# (20.35, 49.4333)
# (20.35, 49.4333)
# (12.6, 40.7667)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (14.2583, 40.675)
# (-144.2, 60.0)
# (-144.2, 60.0)
# (-144.4, 60.0)
# (-144.567, 60.2833)
# (-144.567, 60.2833)
# (-144.533, 60.2167)
# (-144.55, 60.2)
# (-144.583, 60.3167)
# (-142.667, 60.8833)
# (-142.983, 60.9167)
# (-142.85, 60.85)
# (-143.3, 60.8667)
# (-143.36700000000005, 60.7667)
# (-143.183, 60.7833)
# (-144.31799999999996, 61.3086)
# (-144.278, 61.4333)
# (-173.533, 51.55)
# (-147.839, 60.0667)
# (-144.411, 60.5889)
# (-144.40200000000004, 60.5417)
# (-147.74200000000005, 60.325)
# (-147.738, 60.3131)
# (-147.994, 60.0464)
# (-144.58, 59.8056)
# (-144.586, 59.7986)
# (-145.75, 60.55)
# (-179.1, 51.2667)
# (-179.1, 51.2667)
# (-179.1, 51.2667)
# (-179.1, 51.25)
# (-179.1, 51.25)
# (-179.1, 51.25)
# (173.75, 52.5)
# (173.5, 52.45)
# (173.5, 52.45)
# (173.567, 52.4667)
# (173.567, 52.4667)
# (173.567, 52.4667)
# (173.567, 52.4667)
# (-124.083, 40.2667)
# (-123.967, 40.2167)
# (-123.9, 40.2167)
# (-124.017, 40.85)
# (-143.1, 60.2917)
# (-143.1, 60.2917)
# (-143.1, 60.2917)
# (-143.1, 60.2917)
# (-143.1, 60.2917)
# (-147.667, 60.2667)
# (-145.333, 60.7)
# (-144.583, 59.8167)
# (-145.267, 61.3708)
# (-145.267, 61.3708)
# (-145.283, 61.3139)
# (-145.283, 61.3139)
# (-145.328, 61.25)
# (-145.328, 61.25)
# (-145.483, 61.2097)
# (-145.483, 61.2097)
# (-145.483, 61.2097)
# (-145.725, 61.1333)
# (-145.725, 61.1333)
# (-145.911, 61.0611)
# (-145.911, 61.0611)
# (-143.333, 60.9347)
# (-144.254, 61.3047)
# (-144.74200000000005, 61.2319)
# (-144.469, 61.4181)
# (-144.916, 61.3992)
# (-123.95, 40.4694)
# (-149.25, 59.8333)
# (-149.25, 59.8333)
# (-145.65, 60.5333)
# (-145.65, 60.5333)
# (-145.752, 60.5564)
# (-145.659, 60.5675)
# (-145.576, 60.5681)
# (-145.576, 60.5675)
# (-145.891, 60.6183)
# (-145.891, 60.6183)
# (-145.417, 60.9428)
# (-145.27, 60.9772)
# (-145.27, 60.9772)
# (-145.45600000000005, 60.5469)
# (-145.209, 60.4372)
# (-145.227, 60.4458)
# (-145.571, 60.6889)
# (-144.586, 60.1769)
# (-145.53799999999995, 60.6689)
# (-145.49200000000005, 60.7083)
# (-145.49200000000005, 60.7083)
# (-145.333, 60.4775)
# (-146.122, 60.6417)
# (-146.017, 60.7)
# (-146.02200000000005, 60.6917)
# (-146.039, 60.7)
# (-145.95, 60.7292)
# (-145.95, 60.7292)
# (-145.19, 60.5317)
# (-145.2, 60.5208)
# (-145.27100000000004, 60.6333)
# (-145.283, 60.4833)
# (-145.192, 60.535)
# (-145.083, 60.8333)
# (-145.5, 60.8333)
# (-146.5, 60.3333)
# (-146.667, 60.8667)
# (-144.5, 60.4167)
# (-144.583, 60.3333)
# (-144.583, 60.3333)
# (-147.667, 60.3667)
# (-146.333, 61.0167)
# (-145.296, 60.4653)
# (-144.19299999999996, 60.6106)
# (-144.178, 60.6597)
# (-145.136, 60.7092)
# (-144.394, 60.4894)
# (-142.65, 60.7194)
# (-142.592, 60.7569)
# (-143.892, 59.9647)
# (-145.29, 61.3106)
# (139.817, 11.4667)
# (139.817, 11.4667)
# (139.817, 11.4667)
# (138.533, 10.9667)
# (138.533, 10.9667)
# (138.533, 10.9667)
# (138.533, 10.9667)
# (138.217, 10.0)
# (138.217, 10.0)
# (138.267, 10.0)
# (138.267, 10.0)
# (137.733, 8.88333)
# (137.683, 8.91667)
# (137.683, 8.91667)
# (137.683, 8.91667)
# (138.88299999999998, 8.75)
# (138.88299999999998, 8.75)
# (138.88299999999998, 8.75)
# (138.88299999999998, 8.75)
# (-105.895, 21.8733)
# (137.878, 9.22167)
# (137.25, 7.7716699999999985)
# (135.692, 7.61667)
# (136.905, 8.19667)
# (138.29, 9.50333)
# (138.29, 9.50333)
# (137.25, 7.77333)
# (10.0767, 44.0733)
# (-143.665, 61.2611)
# (-144.08, 61.3625)
# (-144.27700000000004, 61.4333)
# (-153.327, 57.1222)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5083, 40.6583)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.2167, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (14.5, 40.65)
# (25.1389, 43.7667)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (8.66667, 44.7167)
# (21.0833, 42.5833)
# (21.25, 42.5833)
# (21.25, 42.5833)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (12.6, 40.7667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (14.25, 40.6667)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-161.20600000000005, 52.5717)
# (-91.0377, 12.4963)
# (-91.0377, 12.4963)
# (166.37, -16.538)
# (166.37, -16.538)
# (-161.20600000000005, 52.5717)
# (-91.0377, 12.4963)
# (-91.0377, 12.4963)
# (-126.357, 44.8897)
# (-161.20600000000005, 52.5717)
# (-91.0377, 12.4963)
# (-91.0377, 12.4963)
# (-126.357, 44.8897)
# (-91.0377, 12.4963)
# (-91.0377, 12.4963)
# (166.37, -16.538)
# (166.37, -16.538)
# (166.37, -16.538)
# (-91.0377, 12.4963)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)
# (134.165, 30.873)

# %%
print(len(indices))
print(len(points_3d))
print(len(np.array(candidates)[indices<len(points_3d)]))
# Out:
# 135721
# 2970
# 4022

# %%
df.iloc[result_index].to_csv("out.csv",index=False,float_format='%.3f')

# %%
import pygplates
import pandas as pd 

data=pd.read_csv("EarthChem_all.csv", sep=',', skipinitialspace=True)
c='AU'
#print(data.columns.values)
#a=data.columns.get_loc(c)
#df=data.iloc[:,[6,7,10,a]]
df = data[['LATITUDE', 'LONGITUDE', 'AGE', c]]
#6,7,10 are the default column numbers for Long, Lat and Age. Please check their position beforehand 
df=df[(df!=0).all(1)]
df=df.dropna()
display(df)    
points = [-151.206313, 55.678344,
          -122.991815,      65.595344,
          -102.931087,      33.901927,
          -127.066947,      27.366931,
           -152.373696,      55.214032,
]

def check_points_within_polygon(lons,lats,polygon_points):
    polygon = pygplates.PolygonOnSphere(zip(polygon_points[1::2],polygon_points[::2]))
    ret=[]
    for lon, lat in zip(lons, lats):
        #print(lon,lat)
        try:
            if polygon.is_point_in_polygon((lat, lon)):
                ret.append(True)
            else:
                ret.append(False)
        except:
            ret.append(False)
    return ret

points_mask = check_points_within_polygon(df['LONGITUDE'], df['LATITUDE'],points )
print(len(points_mask))

df = df[points_mask]
display(df)
# Out:
# /home/mchin/anaconda3/envs/machine_learning/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2,5,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         LATITUDE  LONGITUDE     AGE     AU
# 11242    37.4000  -108.0800    61.0   13.0
# 11243    37.4000  -108.0800    61.0    6.4
# 11244    37.4000  -108.0800    61.0    1.7
# 11245    37.4000  -108.0800    61.0    8.5
# 11246    37.4000  -108.0800    61.0   22.0
# ...          ...        ...     ...    ...
# 443319   33.7753   -82.5639  1495.0  161.0
# 443320   33.7753   -82.5639  1495.0   16.0
# 443408   10.4686   -67.9297   104.5    3.9
# 443410   10.4686   -67.9297   104.5    4.5
# 443428   10.4586   -67.9431   104.5    5.7
#
# [18663 rows x 4 columns]
# 18663
#         LATITUDE  LONGITUDE     AGE     AU
# 11242    37.4000   -108.080   61.00   13.0
# 11243    37.4000   -108.080   61.00    6.4
# 11244    37.4000   -108.080   61.00    1.7
# 11245    37.4000   -108.080   61.00    8.5
# 11246    37.4000   -108.080   61.00   22.0
# ...          ...        ...     ...    ...
# 442725   37.9086   -107.519   28.75    4.3
# 442739   37.9147   -107.556   28.75    8.0
# 442740   37.8753   -107.721   28.75   27.0
# 442746   38.0203   -107.492   28.75    7.0
# 443294   37.7000   -119.167  175.00  210.0
#
# [11872 rows x 4 columns]

# %%
data=pd.read_csv('sphere_mesh.gmt', sep=' ', names=['lon', 'lat'])
points_mask = check_points_within_polygon(data['lon'], data['lat'],points )
print(len(points_mask))

data = data[points_mask]
display(data)
# Out:
# 20472
#           lon    lat
# 31    -148.28  54.00
# 61    -148.28  54.00
# 150   -120.92  59.62
# 268   -120.92  59.62
# 269   -125.89  43.49
# ...       ...    ...
# 18129 -132.43  39.72
# 18130 -130.10  38.20
# 18131 -129.54  40.51
# 18150 -129.00  32.06
# 18163 -130.63  35.90
#
# [340 rows x 2 columns]
