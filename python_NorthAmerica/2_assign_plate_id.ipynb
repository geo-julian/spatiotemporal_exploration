# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import pandas as pd
import Utils

deposits_file_name = 'input_data/NA_positives.csv'
map_extent = [-180, -80, 0, 85], #North America
#map_extent = [-85, -29, -55, 15] #south america


### Remove Everything non-Laramide ###

NA_positives = pd.read_csv(deposits_file_name)

NA_positives = NA_positives[NA_positives['age'] < 81]
data = NA_positives[NA_positives['age'] > 40]
data = data.reset_index(drop=True)

### Continuing as Normal ###

#data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-180, -80, 0, 85])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Mineral Deposits North America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import pandas as pd
import Utils

#deposits_file_name = 'input_data/NA_negatives.csv'
deposits_file_name = 'input_data/NA_negatives.csv'
map_extent = [-180, -80, 0, 85], #North America
#map_extent = [-85, -29, -55, 15] #south america

data=pd.read_csv(deposits_file_name)
lons=data['lon']
lats=data['lat']
ages=data['age']

#plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_left = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

ax.stock_img()
#ax.set_extent(map_extent)
ax.set_extent([-180, -80, 0, 85])
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
                vmin=1, vmax=240, cmap=agegrid_cmap)
plt.title('Volcanic Rocks North America - Ages')
fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
plt.show()

# %%
# deposits_file_name = 'input_data/SA_positives.csv'
# #map_extent = [-180, -80, 0, 85], #North America
# map_extent = [-85, -29, -55, 15] #south america

# ### Remove Mesozoic datapoints ###

# SA_positives = pd.read_csv(deposits_file_name)

# data = SA_positives[SA_positives['age'] < 67]
# data = data.reset_index(drop=True)

# ### Continuing as Normal ###

# #data=pd.read_csv(deposits_file_name)
# lons=data['lon']
# lats=data['lat']
# ages=data['age']

# #plot the map
# fig = plt.figure(figsize=(16,12),dpi=150)
# ax = plt.axes(projection=ccrs.PlateCarree())

# gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=1, color='gray', alpha=0.5, linestyle='--')
# gl.xlabels_top = False
# gl.ylabels_left = False
# gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
# gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
# gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
# gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

# ax.stock_img()
# #ax.set_extent(map_extent)
# ax.set_extent([-85, -29, -55, 15])
# agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
# cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
#                 vmin=1, vmax=240, cmap=agegrid_cmap)
# plt.title('Mineral Deposits South America - Ages')
# fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
# plt.show()

# %%
# deposits_file_name = 'input_data/SA_negatives.csv'
# #map_extent = [-180, -80, 0, 85], #North America
# map_extent = [-85, -29, -55, 15] #south america

# data=pd.read_csv(deposits_file_name)
# lons=data['lon']
# lats=data['lat']
# ages=data['age']

# #plot the map
# fig = plt.figure(figsize=(16,12),dpi=150)
# ax = plt.axes(projection=ccrs.PlateCarree())

# gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=1, color='gray', alpha=0.5, linestyle='--')
# gl.xlabels_top = False
# gl.ylabels_left = False
# gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
# gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
# gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
# gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

# ax.stock_img()
# #ax.set_extent(map_extent)
# ax.set_extent([-85, -29, -55, 15])
# agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')
# cb = ax.scatter(lons, lats, 50, marker='.',c=ages, 
#                 vmin=1, vmax=240, cmap=agegrid_cmap)
# plt.title('Volcanic Rocks South America - Ages')
# fig.colorbar(cb, shrink=0.5, label='Age(Myr)')
# plt.show()

# %%
import pandas as pd
import pygplates
import Utils

NA_positives = pd.read_csv('input_data/NA_positives.csv', index_col='index')
NA_negatives = pd.read_csv('input_data/NA_negatives.csv')

### Remove Everything non-Laramide ###

# NA_positives = pd.read_csv(NA_positives)

NA_positives = NA_positives[NA_positives['age'] < 81]
NA_positives = NA_positives[NA_positives['age'] > 40]
NA_positives = NA_positives.reset_index(drop=True)

### Continuing as Normal ###

config_file_name = 'config_NA.json'


Utils.load_config(config_file_name)
Utils.print_parameters()


lons=NA_positives['lon']
lats=NA_positives['lat']
static_polygons = pygplates.FeatureCollection(Utils.get_parameter('static_polygons_file'))
rotation_model = pygplates.RotationModel(Utils.get_files(Utils.get_parameter('rotation_files')))
plate_ids = Utils.get_plate_id(lons.tolist(), 
                               lats.tolist(), 
                               static_polygons, 
                               rotation_model)


NA_positives['plate_id'] = plate_ids
NA_positives.to_csv('case_AREPS/coreg_input/NA/positive_deposits.csv', index=True, index_label='index')
print(' ')
print("Here are the positives (mineral deposits) from North America...")
display(NA_positives)

print(' ')
print("And now, the negatives (or volcanic rocks!) from North America...")


lons=NA_negatives['lon']
lats=NA_negatives['lat']
static_polygons = pygplates.FeatureCollection(Utils.get_parameter('static_polygons_file'))
rotation_model = pygplates.RotationModel(Utils.get_files(Utils.get_parameter('rotation_files')))
plate_ids = Utils.get_plate_id(lons.tolist(), 
                               lats.tolist(), 
                               static_polygons, 
                               rotation_model)


NA_negatives['plate_id'] = plate_ids

NA_negatives.to_csv('case_AREPS/coreg_input/NA/negative_deposits.csv', index=False)
display(NA_negatives)
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': 'case_AREPS/coreg_input/NA',
#   'coreg_input_files': [ 'negative_deposits.csv',
#                          'positive_deposits.csv',
#                          'deposit_candidates.csv'],
#   'coreg_output_dir': 'coreg_output/NA',
#   'feature_names': [ 'conv_rate',
#                      'dist_nearest_edge',
# ...

# %%
# import pandas as pd
# import pygplates
# import Utils

# SA_positives = pd.read_csv('input_data/SA_positives.csv', index_col='index')
# SA_negatives = pd.read_csv('input_data/SA_negatives.csv')

# SA_positives = SA_positives[SA_positives['age'] < 67]
# SA_positives = SA_positives.reset_index(drop=True)

# config_file_name = 'config_SA.json'


# Utils.load_config(config_file_name)
# Utils.print_parameters()


# lons=SA_positives['lon']
# lats=SA_positives['lat']
# static_polygons = pygplates.FeatureCollection(Utils.get_parameter('static_polygons_file'))
# rotation_model = pygplates.RotationModel(Utils.get_files(Utils.get_parameter('rotation_files')))
# plate_ids = Utils.get_plate_id(lons.tolist(), 
#                                lats.tolist(), 
#                                static_polygons, 
#                                rotation_model)


# SA_positives['plate_id'] = plate_ids
# SA_positives.to_csv('case_AREPS/coreg_input/SA/positive_deposits.csv', index=True, index_label='index')
# print(' ')
# print("Here are the positives (mineral deposits) from South America...")
# display(SA_positives)

# print(' ')
# print("And now, the negatives (or volcanic rocks!) from South America...")


# lons=SA_negatives['lon']
# lats=SA_negatives['lat']
# static_polygons = pygplates.FeatureCollection(Utils.get_parameter('static_polygons_file'))
# rotation_model = pygplates.RotationModel(Utils.get_files(Utils.get_parameter('rotation_files')))
# plate_ids = Utils.get_plate_id(lons.tolist(), 
#                                lats.tolist(), 
#                                static_polygons, 
#                                rotation_model)


# SA_negatives['plate_id'] = plate_ids
# SA_negatives.to_csv('case_AREPS/coreg_input/SA/negative_deposits.csv', index=False)
# #display(SA_negatives)
