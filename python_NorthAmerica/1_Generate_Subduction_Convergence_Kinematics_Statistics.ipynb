# %% [markdown]
# ## Step 1:  Generate Subduction Convergence Kinematics Statistics
#
# In this notebook, we are going to show you how to generate subduction convergence kinematics statistics. The data generated in this step will be used in the subsequent steps of this spatial temporal exploration workflow.
#
# The script finds subduction zones using so-called "topological plate boundaries" in our global plate model. We sample the subduction zones and calculate subduction convergence kinematics statistics at each trench sampling point.
#
# The implementation details can be found in [convergence.py](convergence.py) which depends on the PlateTectonicTools package. You can find the package at [https://github.com/EarthByte/PlateTectonicTools.git](https://github.com/EarthByte/PlateTectonicTools.git).
#
# The parameters being used to run this process can be found in [config.json](config.json).
#
# Relevant parameters:
# * plate_tectonic_tools_path -- the path to the PlateTectonicTools code
# * rotation_files -- location of the rotation files
# * topology_files -- location of the topology files
# * threshold_sampling_distance_degrees -- the default threshold sampling distance along trenches (subduction zones)
# * time.start -- start time
# * time.end -- end time
# * time.step -- time interval between steps
# * velocity_delta_time -- time interval for velocity calculation
# * anchor_plate_id - the anchor plate id
# * convergence_data_filename_prefix -- the prefix of the output files
# * convergence_data_filename_ext -- the extension name of the output files
# * convergence_data_dir -- the name of the folder in which the output files go
#
# You may modify the above parameters and re-run the script to see the differences.
#
# Now, let's run the script and check out the output.

# %% [markdown]
# Before running this notebook is necessary to have all the grid stored in /spatio-temporal-exploration-master-JDiazRod/data/. These are:
#
# AgeGrids
# Carbonate-sed-thickness
# Ocean_Crust_CO2_grids
# Predicted_oceanic_sediment_thickness
#
# Also, make sure that the config.json file(s) is updated with these, as follows:
#
#     "grid_files" : [
#         ["../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc", "seafloor_age"],
#       ["../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc", "carbonate_sediment_thickness"],
#         ["../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc", "total_sediment_thick"],
#         ["../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc", "ocean_crust_carb_percent"]

# %%
#
# SEE HERE! 
# This cell must run first to setup the working environment
#

import glob, os
import convergence , Utils
import pandas as pd

#load the config file
Utils.load_config('config.json')
Utils.print_parameters()
# Out:
# Below are the parameters in use. Check the parameters carefully to ensure a sucussful run.
# { 'agegrid_url': 'https://www.earthbyte.org/webdav/ftp/Data_Collections/Muller_etal_2016_AREPS/Muller_etal_2016_AREPS_Agegrids/Muller_etal_2016_AREPS_Agegrids_v1.17/Muller_etal_2016_AREPS_v1.17_netCDF/Muller_etal_2016_AREPS_v1.17_AgeGrid-{}.nc',
#   'anchor_plate_id': 0,
#   'case_name': 'case_AREPS',
#   'coastlines': '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Coastlines.gpmlz',
#   'convergence_data_dir': './convergence_data/AREPS/',
#   'convergence_data_filename_ext': 'csv',
#   'convergence_data_filename_prefix': 'subStats',
#   'coreg_input_dir': './coreg_input/AREPS/',
#   'coreg_input_files': [ 'deposit_candidates.csv',
#                          'negative_deposits.csv',
#                          'positive_deposits.csv'],
#   'coreg_output_dir': 'coreg_output',
#   'feature_names': [ 'conv_rate',
#                      'dist_nearest_edge',
#                      'subduction_volume_km3y',
#                      'carbonate_sediment_thickness',
#                      'ocean_crust_carb_percent'],
#   'grid_files': [ [ '../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-{time:d}.nc',
#                     'seafloor_age'],
#                   [ '../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_{time:d}.nc',
#                     'carbonate_sediment_thickness'],
#                   [ '../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_{time:d}.nc',
#                     'total_sediment_thick'],
#                   [ '../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_{time:d}.nc',
#                     'ocean_crust_carb_percent']],
#   'machine_learning_engine': 'RFC',
#   'map_extent': [-85, -29, -55, 15],
#   'ml_input_dir': 'ml_input',
#   'ml_output_dir': 'ml_output',
#   'overwrite_existing_convergence_data': True,
#   'plate_tectonic_tools_path': '/workspace/spatio-temporal-exploration-master-JDiazRod/python/../PlateTectonicTools/ptt/',
#   'region_of_interest_polygon_file': '../data/polygon_north_america_julian.csv',
#   'regions': [5, 10, 30],
#   'rotation_files': ['../data/Global_EarthByte_230-0Ma_GK07_AREPS.rot'],
#   'static_polygons_file': '../data/Shapefiles/StaticPolygons/Global_EarthByte_GPlates_PresentDay_StaticPlatePolygons_2015_v1.shp',
#   'terranes': '',
#   'threshold_sampling_distance_degrees': 0.2,
#   'time': {'end': 230, 'start': 0, 'step': 1},
#   'topo_grid': '../data/topo15_3600x1800.nc',
#   'topology_files': [ '../data/Global_EarthByte_230-0Ma_GK07_AREPS_PlateBoundaries.gpml.gz',
#                       '../data/Global_EarthByte_230-0Ma_GK07_AREPS_Topology_BuildingBlocks.gpml.gz'],
#   'vector_files': ['{conv_dir}subStats_{time:.2f}.csv'],
#   'velocity_delta_time': 1}

# %%
# %%capture --no-stdout
print('running convergence...')
print('this may take a while, be patient...')
print('')

#run the convergence script
#this will generate a bunch of Subduction Convergence Kinematics Statistics files
#by default the files are placed in ./convergence_data
convergence.run_it()

# now, let's list all the output files
files = sorted(glob.glob(Utils.get_convergence_dir() + '*'), key=os.path.getmtime)
print('The number of generated files: ', len(files))
print('The first 10 files:')
for i in range(10):
    print(files[i])
# Out:
# running convergence...
# this may take a while, be patient...
#
# generating convergence data ...
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-230.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_230.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_230.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_230.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-229.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_229.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_229.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_229.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-228.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_228.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_228.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_228.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-227.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_227.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_227.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_227.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-226.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_226.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_226.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_226.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-225.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_225.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_225.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_225.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-224.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_224.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_224.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_224.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-223.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_223.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_223.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_223.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-222.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_222.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_222.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_222.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-221.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_221.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_221.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_221.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-220.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_220.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_220.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_220.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-219.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_219.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_219.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_219.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-218.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_218.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_218.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_218.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-217.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_217.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_217.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_217.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-216.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_216.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_216.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_216.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-215.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_215.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_215.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_215.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-214.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_214.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_214.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_214.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-213.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_213.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_213.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_213.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-212.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_212.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_212.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_212.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-211.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_211.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_211.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_211.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-210.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_210.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_210.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_210.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-209.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_209.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_209.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_209.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-208.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_208.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_208.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_208.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-207.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_207.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_207.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_207.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-206.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_206.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_206.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_206.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-205.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_205.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_205.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_205.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-204.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_204.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_204.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_204.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-203.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_203.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_203.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_203.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-202.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_202.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_202.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_202.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-201.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_201.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_201.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_201.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-200.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_200.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_200.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_200.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-199.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_199.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_199.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_199.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-198.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_198.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_198.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_198.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-197.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_197.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_197.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_197.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-196.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_196.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_196.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_196.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-195.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_195.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_195.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_195.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-194.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_194.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_194.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_194.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-193.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_193.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_193.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_193.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-192.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_192.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_192.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_192.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-191.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_191.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_191.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_191.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-190.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_190.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_190.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_190.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-189.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_189.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_189.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_189.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-188.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_188.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_188.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_188.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-187.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_187.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_187.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_187.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-186.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_186.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_186.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_186.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-185.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_185.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_185.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_185.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-184.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_184.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_184.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_184.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-183.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_183.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_183.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_183.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-182.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_182.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_182.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_182.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-181.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_181.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_181.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_181.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-180.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_180.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_180.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_180.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-179.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_179.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_179.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_179.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-178.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_178.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_178.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_178.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-177.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_177.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_177.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_177.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-176.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_176.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_176.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_176.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-175.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_175.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_175.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_175.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-174.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_174.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_174.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_174.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-173.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_173.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_173.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_173.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-172.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_172.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_172.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_172.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-171.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_171.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_171.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_171.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-170.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_170.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_170.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_170.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-169.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_169.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_169.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_169.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-168.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_168.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_168.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_168.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-167.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_167.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_167.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_167.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-166.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_166.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_166.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_166.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-165.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_165.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_165.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_165.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-164.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_164.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_164.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_164.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-163.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_163.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_163.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_163.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-162.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_162.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_162.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_162.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-161.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_161.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_161.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_161.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-160.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_160.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_160.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_160.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-159.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_159.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_159.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_159.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-158.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_158.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_158.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_158.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-157.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_157.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_157.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_157.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-156.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_156.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_156.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_156.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-155.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_155.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_155.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_155.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-154.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_154.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_154.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_154.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-153.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_153.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_153.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_153.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-152.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_152.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_152.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_152.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-151.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_151.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_151.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_151.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-150.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_150.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_150.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_150.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-149.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_149.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_149.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_149.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-148.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_148.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_148.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_148.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-147.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_147.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_147.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_147.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-146.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_146.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_146.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_146.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-145.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_145.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_145.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_145.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-144.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_144.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_144.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_144.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-143.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_143.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_143.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_143.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-142.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_142.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_142.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_142.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-141.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_141.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_141.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_141.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-140.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_140.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_140.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_140.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-139.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_139.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_139.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_139.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-138.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_138.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_138.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_138.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-137.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_137.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_137.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_137.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-136.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_136.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_136.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_136.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-135.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_135.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_135.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_135.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-134.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_134.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_134.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_134.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-133.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_133.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_133.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_133.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-132.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_132.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_132.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_132.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-131.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_131.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_131.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_131.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-130.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_130.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_130.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_130.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-129.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_129.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_129.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_129.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-128.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_128.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_128.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_128.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-127.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_127.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_127.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_127.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-126.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_126.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_126.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_126.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-125.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_125.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_125.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_125.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-124.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_124.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_124.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_124.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-123.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_123.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_123.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_123.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-122.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_122.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_122.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_122.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-121.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_121.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_121.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_121.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-120.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_120.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_120.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_120.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-119.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_119.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_119.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_119.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-118.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_118.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_118.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_118.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-117.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_117.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_117.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_117.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-116.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_116.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_116.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_116.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-115.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_115.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_115.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_115.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-114.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_114.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_114.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_114.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-113.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_113.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_113.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_113.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-112.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_112.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_112.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_112.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-111.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_111.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_111.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_111.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-110.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_110.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_110.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_110.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-109.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_109.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_109.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_109.nc, ocean_crust_carb_percent
# ...
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_39.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_39.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-38.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_38.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_38.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_38.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-37.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_37.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_37.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_37.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-36.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_36.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_36.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_36.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-35.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_35.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_35.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_35.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-34.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_34.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_34.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_34.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-33.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_33.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_33.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_33.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-32.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_32.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_32.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_32.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-31.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_31.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_31.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_31.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-30.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_30.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_30.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_30.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-29.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_29.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_29.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_29.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-28.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_28.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_28.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_28.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-27.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_27.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_27.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_27.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-26.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_26.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_26.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_26.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-25.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_25.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_25.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_25.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-24.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_24.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_24.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_24.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-23.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_23.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_23.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_23.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-22.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_22.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_22.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_22.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-21.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_21.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_21.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_21.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-20.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_20.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_20.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_20.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-19.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_19.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_19.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_19.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-18.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_18.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_18.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_18.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-17.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_17.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_17.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_17.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-16.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_16.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_16.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_16.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-15.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_15.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_15.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_15.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-14.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_14.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_14.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_14.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-13.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_13.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_13.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_13.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-12.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_12.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_12.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_12.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-11.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_11.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_11.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_11.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-10.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_10.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_10.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_10.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-9.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_9.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_9.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_9.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-8.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_8.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_8.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_8.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-7.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_7.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_7.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_7.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-6.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_6.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_6.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_6.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-5.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_5.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_5.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_5.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-4.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_4.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_4.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_4.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-3.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_3.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_3.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_3.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-2.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_2.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_2.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_2.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-1.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_1.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_1.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_1.nc, ocean_crust_carb_percent
# Querying ../data/AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-0.nc, seafloor_age
# Querying ../data/carbonate_sed_thickness/decompacted_sediment_thickness_0.5_0.nc, carbonate_sediment_thickness
# Querying ../data/predicted_oceanic_sediment_thickness/sed_thick_0.2d_0.nc, total_sediment_thick
# Querying ../data/ocean_crust_CO2_grids/ocean_crust_carb_percent_0.nc, ocean_crust_carb_percent
#
# Convergence completed successfully!
# The result data has been saved in ./convergence_data/AREPS/!
# The number of generated files:  231
# The first 10 files:
# ./convergence_data/AREPS/subStats_230.00.csv
# ./convergence_data/AREPS/subStats_229.00.csv
# ./convergence_data/AREPS/subStats_228.00.csv
# ./convergence_data/AREPS/subStats_227.00.csv
# ./convergence_data/AREPS/subStats_226.00.csv
# ./convergence_data/AREPS/subStats_225.00.csv
# ./convergence_data/AREPS/subStats_224.00.csv
# ./convergence_data/AREPS/subStats_223.00.csv
# ./convergence_data/AREPS/subStats_222.00.csv
# ./convergence_data/AREPS/subStats_221.00.csv

# %% [markdown]
# The above cell took a while to finish and created a number of csv files. Each file contains the subduction convergence kinematics statistics at certain time. For example, the file "subStats_230.00.csv" contains data at time 230Ma.
#
# Now, let's open one of the files and see what is inside.

# %%
time=0.
conv_dir = Utils.get_convergence_dir()
pd.read_csv(f"{conv_dir}{Utils.get_parameter('convergence_data_filename_prefix')}_\
{time:0.2f}.{Utils.get_parameter('convergence_data_filename_ext')}")
# Out:
#       trench_lon  trench_lat  conv_rate  conv_angle  trench_abs_rate  \
# 0        -179.97       50.45       6.81      -55.30             1.22
# 1        -179.92      -37.32       4.84      -39.07            -5.01
# 2        -179.82      -37.14       4.87      -38.79            -5.00
# 3        -179.79      -11.20      17.15       68.36            10.46
# 4        -179.72      -36.96       4.90      -38.51            -4.98
# ...          ...         ...        ...         ...              ...
# 3024      179.67      -38.04       4.72      -40.25            -5.08
# 3025      179.74       50.47       6.82      -55.21             1.22
# 3026      179.78      -37.86       4.75      -39.95            -5.06
# 3027      179.88      -37.68       4.78      -39.65            -5.05
# 3028      179.98      -37.50       4.81      -39.36            -5.03
#
#       trench_abs_angle  arc_len  trench_norm  subducting_pid  trench_pid  ...  \
# 0               164.64     0.18         7.02             901         111  ...
# 1                43.98     0.20       293.70             901         806  ...
# 2                44.15     0.20       293.64             901         806  ...
# 3              -135.15     0.17       196.40             901         821  ...
# 4                44.33     0.20       293.58             901         806  ...
# ...                ...      ...          ...             ...         ...  ...
# 3024             43.28     0.20       293.95             901         806  ...
# 3025            164.56     0.18         6.80             901         111  ...
# 3026             43.45     0.20       293.88             901         806  ...
# 3027             43.63     0.20       293.82             901         806  ...
# 3028             43.80     0.20       293.76             901         806  ...
#
#       trench_abs_paral  subducting_abs_rate  subducting_abs_angle  \
# 0                 0.32                -5.93                -63.05
# 1                 3.48                -7.39                  2.96
# 2                 3.48                -7.40                  2.95
# 3                -7.38                 8.64                 96.15
# 4                 3.48                -7.42                  2.95
# ...                ...                  ...                   ...
# 3024              3.48                -7.32                  2.99
# 3025              0.32                -5.94                -62.87
# 3026              3.48                -7.34                  2.98
# 3027              3.48                -7.36                  2.97
# 3028              3.48                -7.37                  2.97
#
#       subducting_abs_ortho  subducting_abs_paral  seafloor_age  \
# 0                     2.69                 -5.29         55.49
# 1                     7.38                  0.38        121.95
# 2                     7.39                  0.38        121.11
# 3                    -0.93                  8.59        100.37
# 4                     7.41                  0.38        121.11
# ...                    ...                   ...           ...
# 3024                  7.31                  0.38        121.95
# 3025                  2.71                 -5.29         54.96
# 3026                  7.33                  0.38        121.95
# 3027                  7.35                  0.38        121.95
# 3028                  7.36                  0.38        121.95
#
#       subduction_volume_km3y  carbonate_sediment_thickness  \
# 0                       0.06                         37.86
# 1                       0.08                         76.80
# 2                       0.08                        104.43
# 3                       0.11                         10.19
# 4                       0.08                        104.43
# ...                      ...                           ...
# 3024                    0.08                         76.80
# 3025                    0.06                         37.98
# 3026                    0.08                         76.80
# 3027                    0.08                         76.80
# 3028                    0.08                         76.80
#
#       total_sediment_thick  ocean_crust_carb_percent
# 0                   126.58                      2.18
# 1                   166.99                      2.46
# 2                   166.55                      2.46
# 3                   156.95                      2.63
# 4                   166.55                      2.46
# ...                    ...                       ...
# 3024                166.99                      2.40
# 3025                126.05                      2.20
# 3026                166.99                      2.40
# 3027                166.99                      2.40
# 3028                166.99                      2.46
#
# [3029 rows x 25 columns]

# %% [markdown]
# There are 3029 rows in the csv file, which means there are 3029 trench sampling points. Each row contains data for each sampled point along trench.
#
# There are 20 columns in the csv file. They are the subduction convergence kinematics statistics. The meaning of each column is listed below.
#
# * 0 longitude of sample point
# * 1 latitude of sample point
# * 2 subducting convergence (relative to trench) velocity magnitude (in cm/yr)
# * 3 subducting convergence velocity obliquity angle (angle between trench normal vector and convergence velocity vector)
# * 4 trench absolute (relative to anchor plate) velocity magnitude (in cm/yr)
# * 5 trench absolute velocity obliquity angle (angle between trench normal vector and trench absolute velocity vector)
# * 6 length of arc segment (in degrees) that current point is on
# * 7 trench normal azimuth angle (clockwise starting at North, ie, 0 to 360 degrees) at current point
# * 8 subducting plate ID
# * 9 trench plate ID
# * 10 distance (in degrees) along the trench line to the nearest trench edge
# * 11 the distance (in degrees) along the trench line from the start edge of the trench
# * 12 convergence velocity orthogonal component(in cm/yr)
# * 13 convergence velocity parallel component(in cm/yr)
# * 14 the trench plate absolute velocity orthogonal component(in cm/yr)
# * 15 the trench plate absolute velocity parallel component(in cm/yr)
# * 16 the subducting plate absolute velocity magnitude (in cm/yr)
# * 17 the subducting plate absolute velocityobliquity angle (in degrees)
# * 18 the subducting plate absolute velocity orthogonal component
# * 19 the subducting plate absolute velocity parallel component
#
# Now, let's draw some maps to visualize the data. The data visualization is important because it allows trends and patterns to be more easily seen.

# %%
# %matplotlib inline

import requests, os, glob
import pygplates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

trench_data = Utils.get_trench_points(0)

#get topological plates boundaries
time = 0
resolved_topologies = []
shared_boundary_sections = []

rotation_files = Utils.get_files(Utils.get_parameter('rotation_files'))
topology_files = Utils.get_files(Utils.get_parameter("topology_files"))
   
#use pygplates to resolve the topologies
pygplates.resolve_topologies(topology_files, rotation_files, resolved_topologies, time, 
                             shared_boundary_sections)

geoms = [t.get_resolved_boundary() for t in resolved_topologies]           

#now, plot the data in a global map    
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()
ax.set_extent([-180, 180, -90, 90])
for geom in geoms:
    lat, lon =zip(*(geom.to_lat_lon_list()))
    plt.plot(lon, lat,
         color='white', linewidth=.5, #the topological plates boundaries in white
         transform=ccrs.Geodetic(),
    )
    
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlocator = mticker.FixedLocator(range(-180,180,30))
gl.ylocator = mticker.FixedLocator(range(-90,90,15))
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

#the subduction sample points are colored by property value.
cb=ax.scatter(trench_data['trench_lon'], trench_data['trench_lat'], 30, marker='.', 
              c=trench_data['dist_nearest_edge']* 6371. * np.pi / 180, cmap=plt.cm.jet)
plt.title('Present-day Subduction Zones Coloured by Distance To Nearest Edge(km)')
fig.colorbar(cb, shrink=0.5, label='Distance To Nearest Edge(km)')
plt.show()

# %% [markdown]
# ##### Take a closer look at the region of interest

# %%
# %matplotlib inline
import Utils

region_of_interest_polygon = Utils.get_region_of_interest_polygon()
#display(region_of_interest_polygon)

mesh_points = Utils.get_mesh_points(region_of_interest_polygon.values.flatten())

#now, plot the data in a regional map    
fig = plt.figure(figsize=(8,8),dpi=96)
ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()
ax.set_extent(Utils.get_region_of_interest_extent())

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlocator = mticker.FixedLocator(range(-180,180,10))
gl.ylocator = mticker.FixedLocator(range(-90,90,10))
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold', 'fontsize': '5'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold', 'fontsize': '5'}

for geom in geoms:
    lat, lon =zip(*(geom.to_lat_lon_list()))
    plt.plot(lon, lat,
         color='white', linewidth=.5, #the topological plates boundaries in white
         transform=ccrs.Geodetic(),
    )
#the subduction sample points are colored by property value. see "color_by" above
cb=ax.scatter(trench_data['trench_lon'], trench_data['trench_lat'], 30, marker='.', 
              c=trench_data['dist_nearest_edge']* 6371. * np.pi / 180, cmap=plt.cm.jet)
plt.plot(region_of_interest_polygon['lon'],region_of_interest_polygon['lat'], transform=ccrs.Geodetic())
ax.scatter(mesh_points['lon'], mesh_points['lat'], 10, marker='.',color='yellow')
plt.title('Present-day Subduction Zones Coloured by Distance To Nearest Edge(km)')
fig.colorbar(cb, shrink=0.5, label='Distance To Nearest Edge(km)')
plt.show()
# Out:
# reading ../data/polygon_north_america_julian.csv

# %% [markdown]
# #### Plot a reconstruction map
# This is a reconstructed map with a paleo-age grid, paleo-coastlines, plate boundaries and subduction teeth.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib.colors import LinearSegmentedColormap
import cartopy.crs as ccrs
from netCDF4 import Dataset
from shapely.geometry.polygon import LinearRing

import Utils, pygplates

time = 0
draw_velocity_vectors = True

#change the extent to see specific area
#map_extent = [-85, -30, -55, 15]
map_extent = [-180, 180, -90, 90]

agegrid_file = Utils.download_agegrid(time)
print(agegrid_file)
agegrid_cmap = Utils.get_age_grid_color_map_from_cpt('agegrid.cpt')

#reconstruct coastlines and topology
print("reconstructing geometries...")

resolved_topologies = []
shared_boundary_sections = []
#use pygplates to resolve the topologies
pygplates.resolve_topologies(topology_files, rotation_files, resolved_topologies, time, 
                             shared_boundary_sections)

#coastlines
reconstructed_geometries = []
pygplates.reconstruct(
                Utils.get_parameter('coastlines'),  
                rotation_files, 
                reconstructed_geometries, 
                time, 0)

#subduction zones
subduction_geoms=[]
Utils.get_subduction_geometries(subduction_geoms, shared_boundary_sections)

#velocity vectors
x,y, u,v = Utils.get_velocity_x_y_u_v(time,pygplates.RotationModel(rotation_files),topology_files)
       
# plot the map
fig = plt.figure(figsize=(16,12),dpi=150)
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=0))
ax.set_extent(map_extent)

if agegrid_file:
    img = Dataset(agegrid_file) #age grid
    cb=ax.imshow(img.variables['z'], origin='lower', transform=ccrs.PlateCarree(),
          extent=[-180, 180, -90, 90], cmap=agegrid_cmap)

#plot coastlines
for geom in reconstructed_geometries:
    lat, lon =zip(*(geom.get_reconstructed_geometry().to_lat_lon_list()))
    plt.plot(lon, lat,
         color='black', linewidth=.5, #the coastlines in black
         transform=ccrs.Geodetic(),
    )

#plot topological plates boundaries
for t in resolved_topologies:
    lat, lon =zip(*(t.get_resolved_boundary().to_lat_lon_list()))
    plt.plot(lon, lat,
         color='blue', linewidth=.5, #the topological plates boundaries in blue
         transform=ccrs.Geodetic(),
    )
 
#plot subduction zones
for geom, aspect in subduction_geoms:
    lat, lon =zip(*(geom.to_lat_lon_list()))
    plt.plot(lon, lat,
         color='blue', linewidth=3, #the subduction zones in blue
         transform=ccrs.Geodetic(),
    )
    teeth = Utils.get_subduction_teeth(lon, lat, triangle_aspect=aspect)
    for tooth in teeth:
        ring = LinearRing(tooth)
        ax.add_geometries([ring], ccrs.PlateCarree(), facecolor='b', edgecolor='black', alpha=1)

 
if draw_velocity_vectors:
    #draw the velocity vectors
    #Some arrows are long and some are very short. To make the plot clearer, we nomalize the velocity magnitude.
    #And use color to denote the different speed.
    u = np.array(u)
    v = np.array(v)
    mag = np.sqrt(u*u+v*v)
    u = u/mag
    v = v/mag
    ax.quiver(x, y, u, v, mag,transform=ccrs.PlateCarree(),cmap='jet')    

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}


if agegrid_file:
    plt.title(f'Reconstruction Map with Paleo-age Grid, Paleo-coastlines and Plate Boundaries at {time} Ma')
    fig.colorbar(cb, shrink=0.5, label='Age(Ma)')
else:
    plt.title(f'Reconstruction Map with Paleo-coastlines and Plate Boundaries at {time} Ma')

plt.show()
# Out:
# Downloading age grids to ./AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-0.nc
# ./AgeGrids/Muller_etal_2016_AREPS_v1.17_AgeGrid-0.nc
# reconstructing geometries...
# /opt/conda/envs/pyGEOL/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:1752: UserWarning: Some vectors at source domain corners may not have been transformed correctly
#   u, v = self.projection.transform_vectors(t, x, y, u, v)

# %% [markdown]
# ##### make a subduction zones animation

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from shapely.geometry.polygon import LinearRing
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import Utils, pygplates

p_time = Utils.get_parameter('time')
start_time = p_time['start'] 
end_time = p_time['end']
time_step = p_time['step']

map_extent = [-180, 180, -90, 90]
 
rotation_files = Utils.get_files(Utils.get_parameter('rotation_files'))
coastlines_file = Utils.get_parameter('coastlines')

for time in range(start_time, end_time+1, 10):
    #coastlines
    reconstructed_geometries = []
    pygplates.reconstruct(
                    coastlines_file, 
                    rotation_files, 
                    reconstructed_geometries, 
                    time, 0)

    #subduction zones
    '''
    topology_files = Utils.get_files(Utils.get_parameter("topology_files"))
    resolved_topologies = []
    shared_boundary_sections = []
    #use pygplates to resolve the topologies
    pygplates.resolve_topologies(topology_files, rotation_files, resolved_topologies, time, 
                                 shared_boundary_sections)
    subduction_geoms=[]
    Utils.get_subduction_geometries(subduction_geoms, shared_boundary_sections)
    '''

    # plot the map
    fig = plt.figure(figsize=(16,12),dpi=144)
    ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=0))
    ax.set_extent(map_extent)

    #plot coastlines
    for geom in reconstructed_geometries:
        lat, lon =zip(*(geom.get_reconstructed_geometry().to_lat_lon_list()))
        plt.plot(lon, lat,
             color='black', linewidth=.5, #the coastlines in black
             transform=ccrs.Geodetic(),
        )

    #plot subduction zones
    '''
    for geom, aspect in subduction_geoms:
        lat, lon =zip(*(geom.to_lat_lon_list()))
        plt.plot(lon, lat,
             color='blue', linewidth=1, #the subduction zones in blue
             transform=ccrs.Geodetic(),
        )
        teeth = Utils.get_subduction_teeth(lon, lat, triangle_aspect=aspect)
        for tooth in teeth:
            ring = LinearRing(tooth)
            ax.add_geometries([ring], ccrs.PlateCarree(), facecolor='b', edgecolor='black', alpha=1)
    '''

    trench_data = Utils.get_trench_points(time)
    #the subduction sample points are colored by property value. see "color_by" above
    cb=ax.scatter(trench_data['trench_lon'], trench_data['trench_lat'], 50, marker='.', 
                  c=trench_data['dist_nearest_edge']* 6371. * np.pi / 180, cmap=plt.cm.jet, vmax=3000, vmin=0)

    fig.colorbar(cb, shrink=0.5, label='Distance To Nearest Edge(km)')

    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=1, color='gray', alpha=0.5, linestyle='--')
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlocator = mticker.FixedLocator([-180, -150, -120, -90, -60, -30, 0, 30, 60, 90, 120, 150, 180])
    gl.ylocator = mticker.FixedLocator([-90, -75, -60, -45, -30, -15, 0, 15, 30, 45, 60, 75, 90])
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'color': 'gray', 'weight': 'bold'}
    gl.ylabel_style = {'color': 'gray', 'weight': 'bold'}

    plt.title(f'Subduction Zones at {time} Ma')
    plt.savefig(Utils.get_tmp_dir() + f'subduction_zones_{time}_Ma.png',bbox_inches='tight',pad_inches=0)
    print(f'plotting {time}Ma')
    plt.close()
    #plt.show()
# Out:
# plotting 0Ma
# plotting 10Ma
# plotting 20Ma
# plotting 30Ma
# plotting 40Ma
# plotting 50Ma
# plotting 60Ma
# plotting 70Ma
# plotting 80Ma
# plotting 90Ma
# plotting 100Ma
# plotting 110Ma
# plotting 120Ma
# plotting 130Ma
# plotting 140Ma
# plotting 150Ma
# plotting 160Ma
# plotting 170Ma
# plotting 180Ma
# plotting 190Ma
# plotting 200Ma
# plotting 210Ma
# plotting 220Ma
# plotting 230Ma

# %%
# %%capture --no-stdout

import moviepy.editor as mpy
import Utils

p_time = Utils.get_parameter('time')
start_time = p_time['start'] 
end_time = p_time['end']
time_step = p_time['step']

frame_list = [Utils.get_tmp_dir() + f'subduction_zones_{time}_Ma.png' for time in range(start_time, end_time+1, 10)]
clip = mpy.ImageSequenceClip(frame_list, fps=2)
clip.write_gif(Utils.get_tmp_dir() + "subduction_zones.gif")
clip.write_videofile(Utils.get_tmp_dir() + "subduction_zones.mp4")
print('done')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-4a4a0fcafd3f> in <module>
# ----> 1 import moviepy.editor as mpy
#       2 import Utils
#       3
#       4 p_time = Utils.get_parameter('time')
#       5 start_time = p_time['start']
#
# ModuleNotFoundError: No module named 'moviepy'

# %%
import io, base64

from IPython.display import HTML

video = io.open(Utils.get_tmp_dir() + "subduction_zones.mp4", 'r+b').read()

encoded = base64.b64encode(video)

HTML(data='''<video width=960 alt="subduction zones animation" controls>

<source src="data:video/mp4;base64,{0}" type="video/mp4" /> </video>'''.format(encoded.decode('ascii')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ba35028e06c1> in <module>
#       3 from IPython.display import HTML
#       4
# ----> 5 video = io.open(Utils.get_tmp_dir() + "subduction_zones.mp4", 'r+b').read()
#       6
#       7 encoded = base64.b64encode(video)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/subduction_zones.mp4'

# %% [markdown]
# #### This is the end of step 1 and now open the step 2 notebook --  "2_Plot_and_Select_Mineral_Resources.ipynb"
